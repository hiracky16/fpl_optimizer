# %%
import pandas as pd
import pulp

# %%
data = pd.read_csv('./app/data/elements.csv')

# %%
data.head()
# Out:
#     id                                 name element_type_name team_name  \
# 0  330                        Harry Maguire               DEF   Man Utd
# 1  344                       Anthony Elanga               MID   Man Utd
# 2  341                    Aaron Wan-Bissaka               DEF   Man Utd
# 3  331  Frederico Rodrigues de Paula Santos               MID   Man Utd
# 4  343                     Brandon Williams               DEF   Man Utd
#
#    total_points  now_cost
# 0            69        50
# 1            59        50
# 2            41        45
# 3            93        55
# 4            36        40

# %%
# const
# Position name
POSITIONS = ['GKP', 'DEF', 'MID', 'FWD']
# Limit on the number of players by position
PLAYER_LIMIT_BY_POSITIONS = {'GKP': 2, 'DEF': 5, 'MID': 5, 'FWD': 3}
# Limit on the number of players
TOTAL_PLAYERS = sum([p for p in PLAYER_LIMIT_BY_POSITIONS.values()])
# Limit on the number of players on the same team
SAME_TEAM_LIMIT = 3
# Limit on cost
COST_LIMIT = 970
# favorit team （default: none）
# FAVORIT_TEAM = 'Man Utd'
FAVORIT_TEAMS = ['Man Utd']
# EXCLUSIVE TEAMS
EXCLUSIVE_TEAMS = ['West Ham']

# %%
fun = lambda x: pulp.LpVariable(f'{x.id}_{x.element_type_name}_{x.team_name}', cat='Binary')
data['variables'] = list(data.apply(fun, axis=1))

# %%
prob = pulp.LpProblem('fpl_planner', sense = pulp.LpMaximize)
# ポジションごとの人数の制約
for p in data.element_type_name.unique():
    dt = data[data.element_type_name == p]
    prob += pulp.lpSum(dt.variables) == PLAYER_LIMIT_BY_POSITIONS[p]

# %%
# 同じチーム 3 人の制約
for t in data.team_name.unique():
    dt = data[data.team_name == t]
    prob += pulp.lpSum(dt.variables) <= SAME_TEAM_LIMIT

# お気に入りチーム選手を絶対一人入れる
for t in FAVORIT_TEAMS:
    dt = data[data.team_name == t]
    prob += pulp.lpSum(dt.variables) >= 1

# 除外するチーム
for t in EXCLUSIVE_TEAMS:
    dt = data[data.team_name == t]
    prob += pulp.lpSum(dt.variables) == 0

# %%
# 目的関数
prob += pulp.lpDot(data.total_points, data.variables)
# コストの制限
prob += pulp.lpDot(data.now_cost, data.variables) <= COST_LIMIT
# 全体の選手数の制限
prob += pulp.lpSum(data.variables) == TOTAL_PLAYERS
# Out:
# /Users/nori/.pyenv/versions/3.8.6/lib/python3.8/site-packages/pulp/pulp.py:1704: UserWarning: Overwriting previously set objective.
#   warnings.warn("Overwriting previously set objective.")

# %%
print(prob)
# Out:
# fpl_planner:
# MAXIMIZE
# 44*101_MID_Brighton + 2*102_GKP_Brighton + 89*103_FWD_Brighton + 88*104_MID_Brighton + 48*105_DEF_Brighton + 92*106_DEF_Brighton + 61*107_MID_Brighton + 59*108_DEF_Brighton + 95*109_DEF_Brighton + 107*10_DEF_Arsenal + 98*110_FWD_Brighton + 141*111_MID_Brighton + 126*112_DEF_Brighton + 126*113_GKP_Brighton + 74*114_DEF_Brighton + 13*115_MID_Brighton + 93*116_MID_Brighton + 58*117_MID_Brighton + 58*118_MID_Brighton + 5*119_MID_Brighton + 55*11_FWD_Arsenal + 27*120_MID_Brighton + 2*121_MID_Brighton + 87*127_DEF_Chelsea + 130*128_DEF_Chelsea + 128*129_DEF_Chelsea + 125*12_MID_Arsenal + 106*130_MID_Chelsea + 14*131_MID_Chelsea + 76*132_MID_Chelsea + 19*133_GKP_Chelsea + 79*134_MID_Chelsea + 79*135_MID_Chelsea + 52*136_MID_Chelsea + 62*137_FWD_Chelsea + 4*138_DEF_Chelsea + 55*139_DEF_Chelsea + 179*13_MID_Arsenal + 77*140_MID_Chelsea + 99*141_DEF_Chelsea + 169*142_MID_Chelsea + 30*143_DEF_Chelsea + 49*144_MID_Chelsea + 112*145_FWD_Chelsea + 141*146_DEF_Chelsea + 130*147_GKP_Chelsea + 140*148_MID_Chelsea + 49*149_MID_Chelsea + 75*14_DEF_Arsenal + 92*150_FWD_Chelsea + 119*152_GKP_Crystal_Palace + 17*153_DEF_Crystal_Palace + 54*154_MID_Crystal_Palace + 58*155_FWD_Crystal_Palace + 73*156_DEF_Crystal_Palace + 59*157_DEF_Crystal_Palace + 19*158_MID_Crystal_Palace + 77*159_MID_Crystal_Palace + 135*15_GKP_Arsenal + 150*160_MID_Crystal_Palace + 86*161_MID_Crystal_Palace + 30*162_GKP_Crystal_Palace + 34*163_MID_Crystal_Palace + 4*164_MID_Crystal_Palace + 124*165_DEF_Crystal_Palace + 87*166_FWD_Crystal_Palace + 123*167_DEF_Crystal_Palace + 61*168_FWD_Crystal_Palace + 31*169_MID_Crystal_Palace + 146*16_DEF_Arsenal + 109*170_DEF_Crystal_Palace + 73*171_MID_Crystal_Palace + 4*172_MID_Crystal_Palace + 1*174_DEF_Crystal_Palace + 13*176_GKP_Everton + 30*177_FWD_Everton + 79*178_DEF_Everton + 66*179_MID_Everton + 49*17_DEF_Arsenal + 102*180_DEF_Everton + 35*181_MID_Everton + 116*182_GKP_Everton + 58*183_MID_Everton + 18*184_MID_Everton + 90*185_MID_Everton + 78*186_MID_Everton + 3*187_MID_Everton + 24*188_DEF_Everton + 106*189_MID_Everton + 32*18_MID_Arsenal + 12*190_MID_Everton + 64*191_FWD_Everton + 62*192_DEF_Everton + 45*193_DEF_Everton + 42*194_DEF_Everton + 100*195_MID_Everton + 7*196_DEF_Everton + 83*199_DEF_Everton + 110*19_MID_Arsenal + 48*1_DEF_Arsenal + 1*20_DEF_Arsenal + 12*21_MID_Arsenal + 60*221_DEF_Leeds + 55*222_DEF_Leeds + 61*223_MID_Leeds + 38*224_MID_Leeds + 85*225_MID_Leeds + 80*226_DEF_Leeds + 28*227_FWD_Leeds + 77*228_DEF_Leeds + 34*229_MID_Leeds + 23*230_DEF_Leeds + 91*231_MID_Leeds + 145*232_MID_Leeds + 117*233_MID_Leeds + 19*234_MID_Leeds + 35*235_DEF_Leeds + 2*236_GKP_Leeds + 15*237_FWD_Leeds + 106*238_GKP_Leeds + 22*239_DEF_Leeds + 1*23_MID_Arsenal + 6*240_MID_Leeds + 3*241_MID_Leeds + 43*242_FWD_Leeds + 2*243_DEF_Leeds + 131*248_GKP_Leicester + 39*249_DEF_Leicester + 4*250_DEF_Leicester + 40*251_MID_Leicester + 24*252_MID_Leicester + 11*253_DEF_Leicester + 3*254_GKP_Leicester + 133*255_FWD_Leicester + 35*256_DEF_Leicester + 55*257_DEF_Leicester + 75*258_DEF_Leicester + 120*259_MID_Leicester + 35*260_MID_Leicester + 181*261_MID_Leicester + 80*262_FWD_Leicester + 8*263_MID_Leicester + 137*264_MID_Leicester + 41*265_MID_Leicester + 70*266_MID_Leicester + 66*267_DEF_Leicester + 29*268_DEF_Leicester + 36*269_MID_Leicester + 50*270_DEF_Leicester + 70*271_FWD_Leicester + 17*272_DEF_Leicester + 1*273_DEF_Leicester + 38*274_MID_Liverpool + 110*275_MID_Liverpool + 170*276_DEF_Liverpool + 69*277_MID_Liverpool + 42*278_MID_Liverpool + 62*279_FWD_Liverpool + 183*280_DEF_Liverpool + 176*281_GKP_Liverpool + 97*282_MID_Liverpool + 265*283_MID_Liverpool + 186*284_DEF_Liverpool + 208*285_DEF_Liverpool + 22*286_DEF_Liverpool + 65*287_MID_Liverpool + 175*288_FWD_Liverpool + 8*289_GKP_Liverpool + 120*28_FWD_Arsenal + 33*290_DEF_Liverpool + 40*291_MID_Liverpool + 42*292_DEF_Liverpool + 64*293_MID_Liverpool + 12*294_MID_Liverpool + 4*295_DEF_Nott'm_Forest + 85*299_DEF_Man_City + 83*29_MID_Aston_Villa + 10*2_GKP_Arsenal + 124*300_MID_Man_City + 19 ...
# SUBJECT TO
# _C1: 105_DEF_Brighton + 106_DEF_Brighton + 108_DEF_Brighton + 109_DEF_Brighton
#  + 10_DEF_Arsenal + 112_DEF_Brighton + 114_DEF_Brighton + 122_DEF_Brighton
#  + 127_DEF_Chelsea + 128_DEF_Chelsea + 129_DEF_Chelsea + 138_DEF_Chelsea
#  + 139_DEF_Chelsea + 141_DEF_Chelsea + 143_DEF_Chelsea + 146_DEF_Chelsea
#  + 14_DEF_Arsenal + 151_DEF_Chelsea + 153_DEF_Crystal_Palace
#  + 156_DEF_Crystal_Palace + 157_DEF_Crystal_Palace + 165_DEF_Crystal_Palace
#  + 167_DEF_Crystal_Palace + 16_DEF_Arsenal + 170_DEF_Crystal_Palace
#  + 174_DEF_Crystal_Palace + 178_DEF_Everton + 17_DEF_Arsenal + 180_DEF_Everton
#  + 188_DEF_Everton + 192_DEF_Everton + 193_DEF_Everton + 194_DEF_Everton
#  + 196_DEF_Everton + 197_DEF_Everton + 198_DEF_Everton + 199_DEF_Everton
#  + 1_DEF_Arsenal + 201_DEF_Fulham + 206_DEF_Fulham + 208_DEF_Fulham
#  + 209_DEF_Fulham + 20_DEF_Arsenal + 215_DEF_Fulham + 217_DEF_Fulham
#  + 221_DEF_Leeds + 222_DEF_Leeds + 226_DEF_Leeds + 228_DEF_Leeds
#  + 230_DEF_Leeds + 235_DEF_Leeds + 239_DEF_Leeds + 243_DEF_Leeds
#  + 244_DEF_Leeds + 249_DEF_Leicester + 250_DEF_Leicester + 253_DEF_Leicester
#  + 256_DEF_Leicester + 257_DEF_Leicester + 258_DEF_Leicester
#  + 267_DEF_Leicester + 268_DEF_Leicester + 26_DEF_Arsenal + 270_DEF_Leicester
#  + 272_DEF_Leicester + 273_DEF_Leicester + 276_DEF_Liverpool
#  + 280_DEF_Liverpool + 284_DEF_Liverpool + 285_DEF_Liverpool
#  + 286_DEF_Liverpool + 290_DEF_Liverpool + 292_DEF_Liverpool
#  + 295_DEF_Nott'm_Forest + 298_DEF_Liverpool + 299_DEF_Man_City
#  + 302_DEF_Man_City + 306_DEF_Man_City + 308_DEF_Man_City + 309_DEF_Man_City
#  + 312_DEF_Man_City + 313_DEF_Man_City + 320_DEF_Man_City + 322_DEF_Man_City
#  + 328_DEF_Man_Utd + 329_DEF_Man_Utd + 32_DEF_Aston_Villa + 330_DEF_Man_Utd
#  + 332_DEF_Man_Utd + 334_DEF_Man_Utd + 337_DEF_Man_Utd + 339_DEF_Man_Utd
#  + 33_DEF_Aston_Villa + 341_DEF_Man_Utd + 342_DEF_Man_Utd + 343_DEF_Man_Utd
#  + 350_DEF_Newcastle + 351_DEF_Newcastle + 352_DEF_Newcastle
#  + 357_DEF_Newcastle + 358_DEF_Newcastle + 360_DEF_Newcastle
#  + 362_DEF_Newcastle + 363_DEF_Newcastle + 364_DEF_Newcastle
#  + 366_DEF_Newcastle + 367_DEF_Newcastle + 372_DEF_Newcastle
#  + 377_DEF_Newcastle + 379_DEF_Nott'm_Forest + 385_DEF_Nott'm_Forest
#  + 386_DEF_Nott'm_Forest + 388_DEF_Nott'm_Forest + 389_DEF_Nott'm_Forest
#  + 38_DEF_Aston_Villa + 392_DEF_Nott'm_Forest + 393_DEF_Nott'm_Forest
#  + 399_DEF_Nott'm_Forest + 39_DEF_Aston_Villa + 404_DEF_Southampton
#  + 409_DEF_Southampton + 410_DEF_Southampton + 413_DEF_Southampton
#  + 414_DEF_Southampton + 417_DEF_Southampton + 419_DEF_Southampton
#  + 420_DEF_Southampton + 423_DEF_Southampton + 429_DEF_Spurs + 430_DEF_Spurs
#  + 432_DEF_Spurs + 435_DEF_Spurs + 436_DEF_Spurs + 438_DEF_Spurs
#  + 439_DEF_Spurs + 43_DEF_Aston_Villa + 442_DEF_Spurs + 443_DEF_Spurs
#  + 445_DEF_Spurs + 448_DEF_Spurs + 44_DEF_Aston_Villa + 456_DEF_West_Ham
#  + 457_DEF_West_Ham + 459_DEF_West_Ham + 461_DEF_West_Ham + 462_DEF_West_Ham
#  + 463_DEF_West_Ham + 470_DEF_West_Ham + 471_DEF_West_Ham + 472_DEF_West_Ham
#  + 474_DEF_Wolves + 475_DEF_Wolves + 477_DEF_Wolves + 482_DEF_Wolves
#  + 484_DEF_Wolves + 487_DEF_Wolves + 489_DEF_Wolves + 494_DEF_Wolves
#  + 498_DEF_Liverpool + 499_DEF_Liverpool + 500_DEF_Liverpool
#  + 501_DEF_Liverpool + 504_DEF_Man_Utd + 507_DEF_Nott'm_Forest
#  + 50_DEF_Aston_Villa + 510_DEF_Brentford + 511_DEF_Nott'm_Forest
#  + 513_DEF_Spurs + 516_DEF_Wolves + 56_DEF_Aston_Villa + 57_DEF_Bournemouth
#  + 59_DEF_Bournemouth + 5_DEF_Arsenal + 65_DEF_Bournemouth
#  + 71_DEF_Bournemouth + 73_DEF_Bournemouth + 76_DEF_Bournemouth
#  + 78_DEF_Brentford + 82_DEF_Brentford + 84_DEF_Brentford + 85_DEF_Brentford
#  + 8_DEF_Arsenal + 90_DEF_Brentford + 91_DEF_Brentford + 92_DEF_Brentford
#  + 96_DEF_Brentford + 98_DEF_Brentford = 5
#
# _C2: 101_MID_Brighton + 104_MID_Brighton + 107_MID_Brighton + 111_MID_Brighton
#  + 115_MID_Brighton + 116_MID_Brighton + 117_MID_Brighton + 118_MID_Brighton
#  + 119_MID_Brighton + 120_MID_Brighton + 121_MID_Brighton + 124_MID_Brighton
#  + 126_MID_Brighton + 12_MID_Arsenal + 130_MID_Chelsea + 131_MID_Chelsea
#  + 132_MID_Chelsea + 134_MID_Chelsea + 135_MID_Chelsea + 136_MID_Chelsea
#  + 13_MID_Arsenal + 140_MID_Chelsea + 142_MID_Chelsea + 144_MID_Chelsea
#  + 148_MID_Chelsea + 149_MID_Chelsea + 154_MID_Crystal_Palace
#  + 158_MID_Crystal_Palace + 159_MID_Crystal_Palace + 160_MID_Crystal_Palace
#  + 161_MID_Crystal_Palace + 163_MID_Crystal_Palace + 164_MID_Crystal_Palace
#  + 169_MID_Crystal_Palace + 171_MID_Crystal_Palace + 172_MID_Crystal_Palace
#  + 173_MID_Crystal_Palace + 179_MID_Everton + 181_MID_Everton
#  + 183_MID_Everton + 184_MID_Everton + 185_MID_Everton + 186_MID_Everton
#  + 187_MID_Everton + 189_MID_Everton + 18_MID_Arsenal + 190_MID_Everton
#  + 195_MID_Everton + 19_MID_Arsenal + 200_MID_Fulham + 202_MID_Fulham
#  + 203_MID_Fulham + 204_MID_Fulham + 205_MID_Fulham + 211_MID_Fulham
#  + 212_MID_Fulham + 214_MID_Fulham + 216_MID_Fulham + 21_MID_Arsenal
#  + 220_MID_Fulham + 223_MID_Leeds + 224_MID_Leeds + 225_MID_Leeds
#  + 229_MID_Leeds + 22_MID_Arsenal + 231_MID_Leeds + 232_MID_Leeds
#  + 233_MID_Leeds + 234_MID_Leeds + 23_MID_Arsenal + 240_MID_Leeds
#  + 241_MID_Leeds + 245_MID_Leeds + 246_MID_Leeds + 247_MID_Leeds
#  + 251_MID_Leicester + 252_MID_Leicester + 259_MID_Leicester + 25_MID_Arsenal
#  + 260_MID_Leicester + 261_MID_Leicester + 263_MID_Leicester
#  + 264_MID_Leicester + 265_MID_Leicester + 266_MID_Leicester
#  + 269_MID_Leicester + 274_MID_Liverpool + 275_MID_Liverpool
#  + 277_MID_Liverpool + 278_MID_Liverpool + 27_MID_Arsenal + 282_MID_Liverpool
#  + 283_MID_Liverpool + 287_MID_Liverpool + 291_MID_Liverpool
#  + 293_MID_Liverpool + 294_MID_Liverpool + 296_MID_Liverpool
#  + 29_MID_Aston_Villa + 300_MID_Man_City + 301_MID_Man_City + 303_MID_Man_City
#  + 304_MID_Chelsea + 305_MID_Man_City + 311_MID_Man_City + 314_MID_Man_City
#  + 315_MID_Man_City + 316_MID_Man_City + 317_MID_Man_City
#  + 321_MID_Southampton + 325_MID_Man_City + 331_MID_Man_Utd + 333_MID_Man_Utd
#  + 335_MID_Man_Utd + 336_MID_Man_Utd + 338_MID_Man_Utd + 340_MID_Man_Utd
#  + 344_MID_Man_Utd + 346_MID_Fulham + 347_MID_Man_Utd + 349_MID_Newcastle
#  + 34_MID_Aston_Villa + 359_MID_Newcastle + 365_MID_Newcastle
#  + 368_MID_Newcastle + 369_MID_Newcastle + 36_MID_Aston_Villa
#  + 370_MID_Newcastle + 371_MID_Newcastle + 373_MID_Newcastle
#  + 374_MID_Newcastle + 375_MID_Newcastle + 378_MID_Nott'm_Forest
#  + 37_MID_Aston_Villa + 381_MID_Nott'm_Forest + 383_MID_Nott'm_Forest
#  + 384_MID_Nott'm_Forest + 387_MID_Nott'm_Forest + 390_MID_Nott'm_Forest
#  + 395_MID_Nott'm_Forest + 396_MID_Nott'm_Forest + 3_MID_Arsenal
#  + 400_MID_Southampton + 402_MID_Southampton + 403_MID_Southampton
#  + 405_MID_Southampton + 406_MID_Southampton + 407_MID_Southampton
#  + 412_MID_Southampton + 415_MID_Southampton + 416_MID_Southampton
#  + 418_MID_Southampton + 41_MID_Aston_Villa + 428_MID_Spurs
#  + 42_MID_Aston_Villa + 431_MID_Spurs + 433_MID_Spurs + 434_MID_Spurs
#  + 437_MID_Spurs + 440_MID_Spurs + 441_MID_Spurs + 444_MID_Spurs
#  + 446_MID_Spurs + 449_MID_Spurs + 450_MID_Spurs + 452_MID_Spurs
#  + 45_MID_Aston_Villa + 460_MID_West_Ham + 464_MID_West_Ham + 465_MID_West_Ham
#  + 466_MID_West_Ham + 467_MID_West_Ham + 468_MID_West_Ham + 469_MID_West_Ham
#  + 46_MID_Aston_Villa + 479_MID_Wolves + 47_MID_Aston_Villa + 480_MID_Wolves
#  + 481_MID_Wolves + 483_MID_Wolves + 485_MID_Wolves + 486_MID_Wolves
#  + 48_MID_Aston_Villa + 490_MID_Wolves + 491_MID_Wolves + 493_MID_Wolves
#  + 49_MID_Aston_Villa + 4_MID_Arsenal + 503_MID_Wolves + 505_MID_Bournemouth
#  + 506_MID_Leeds + 508_MID_Leeds + 509_MID_West_Ham + 512_MID_Southampton
#  + 514_MID_Crystal_Palace + 515_MID_Brentford + 519_MID_Man_Utd
#  + 51_MID_Aston_Villa + 53_MID_Aston_Villa + 55_MID_Aston_Villa
#  + 58_MID_Bournemouth + 60_MID_Bournemouth + 61_MID_Bournemouth
#  + 63_MID_Bournemouth + 64_MID_Bournemouth + 67_MID_Bournemouth
#  + 68_MID_Bournemouth + 69_MID_Bournemouth + 6_MID_Arsenal
#  + 70_MID_Bournemouth + 74_MID_Bournemouth + 75_MID_Bournemouth
#  + 79_MID_Brentford + 7_MID_Arsenal + 83_MID_Brentford + 86_MID_Brentford
#  + 87_MID_Brentford + 88_MID_Brentford + 89_MID_Brentford + 93_MID_Brentford
#  + 94_MID_Brentford + 99_MID_Brentford + 9_MID_Arsenal = 5
#
# _C3: 103_FWD_Brighton + 110_FWD_Brighton + 11_FWD_Arsenal + 123_FWD_Brighton
#  + 125_FWD_Brighton + 137_FWD_Chelsea + 145_FWD_Chelsea + 150_FWD_Chelsea
#  + 155_FWD_Crystal_Palace + 166_FWD_Crystal_Palace + 168_FWD_Crystal_Palace
#  + 177_FWD_Everton + 191_FWD_Everton + 210_FWD_Fulham + 218_FWD_Fulham
#  + 219_FWD_Fulham + 227_FWD_Leeds + 237_FWD_Leeds + 242_FWD_Leeds
#  + 255_FWD_Leicester + 262_FWD_Leicester + 271_FWD_Leicester
#  + 279_FWD_Liverpool + 288_FWD_Liverpool + 28_FWD_Arsenal + 297_FWD_Liverpool
#  + 30_FWD_Aston_Villa + 318_FWD_Man_City + 319_FWD_Man_City + 323_FWD_Man_City
#  + 326_FWD_Man_Utd + 345_FWD_Man_Utd + 354_FWD_Newcastle + 356_FWD_Newcastle
#  + 361_FWD_Newcastle + 380_FWD_Nott'm_Forest + 391_FWD_Nott'm_Forest
#  + 394_FWD_Nott'm_Forest + 397_FWD_Nott'm_Forest + 408_FWD_Southampton
#  + 40_FWD_Aston_Villa + 411_FWD_Southampton + 427_FWD_Spurs + 447_FWD_Spurs
#  + 453_FWD_Spurs + 454_FWD_Spurs + 458_FWD_West_Ham + 476_FWD_Wolves
#  + 488_FWD_Wolves + 496_FWD_Crystal_Palace + 52_FWD_Aston_Villa
#  + 54_FWD_Aston_Villa + 62_FWD_Bournemouth + 66_FWD_Bournemouth
#  + 80_FWD_Brentford + 95_FWD_Brentford + 97_FWD_Brentford = 3
#
# _C4: 100_GKP_Brentford + 102_GKP_Brighton + 113_GKP_Brighton + 133_GKP_Chelsea
#  + 147_GKP_Chelsea + 152_GKP_Crystal_Palace + 15_GKP_Arsenal
#  + 162_GKP_Crystal_Palace + 175_GKP_Crystal_Palace + 176_GKP_Everton
#  + 182_GKP_Everton + 207_GKP_Fulham + 213_GKP_Fulham + 236_GKP_Leeds
#  + 238_GKP_Leeds + 248_GKP_Leicester + 24_GKP_Arsenal + 254_GKP_Leicester
#  + 281_GKP_Liverpool + 289_GKP_Liverpool + 2_GKP_Arsenal + 307_GKP_Man_City
#  + 310_GKP_Man_City + 31_GKP_Aston_Villa + 324_GKP_Man_City + 327_GKP_Man_Utd
#  + 348_GKP_Man_Utd + 353_GKP_Newcastle + 355_GKP_Newcastle
#  + 35_GKP_Aston_Villa + 376_GKP_Newcastle + 382_GKP_Nott'm_Forest
#  + 398_GKP_Nott'm_Forest + 401_GKP_Southampton + 421_GKP_Southampton
#  + 422_GKP_Southampton + 424_GKP_Southampton + 425_GKP_Spurs + 426_GKP_Spurs
#  + 451_GKP_Spurs + 455_GKP_West_Ham + 473_GKP_West_Ham + 478_GKP_Wolves
#  + 492_GKP_Wolves + 495_GKP_Crystal_Palace + 497_GKP_Liverpool
#  + 502_GKP_Man_City + 517_GKP_Brentford + 518_GKP_Nott'm_Forest
#  + 72_GKP_Bournemouth + 77_GKP_Bournemouth + 81_GKP_Brentford = 2
#
# _C5: 326_FWD_Man_Utd + 327_GKP_Man_Utd + 328_DEF_Man_Utd + 329_DEF_Man_Utd
#  + 330_DEF_Man_Utd + 331_MID_Man_Utd + 332_DEF_Man_Utd + 333_MID_Man_Utd
#  + 334_DEF_Man_Utd + 335_MID_Man_Utd + 336_MID_Man_Utd + 337_DEF_Man_Utd
#  + 338_MID_Man_Utd + 339_DEF_Man_Utd + 340_MID_Man_Utd + 341_DEF_Man_Utd
#  + 342_DEF_Man_Utd + 343_DEF_Man_Utd + 344_MID_Man_Utd + 345_FWD_Man_Utd
#  + 347_MID_Man_Utd + 348_GKP_Man_Utd + 504_DEF_Man_Utd + 519_MID_Man_Utd <= 3
#
# _C6: 221_DEF_Leeds + 222_DEF_Leeds + 223_MID_Leeds + 224_MID_Leeds
#  + 225_MID_Leeds + 226_DEF_Leeds + 227_FWD_Leeds + 228_DEF_Leeds
#  + 229_MID_Leeds + 230_DEF_Leeds + 231_MID_Leeds + 232_MID_Leeds
#  + 233_MID_Leeds + 234_MID_Leeds + 235_DEF_Leeds + 236_GKP_Leeds
#  + 237_FWD_Leeds + 238_GKP_Leeds + 239_DEF_Leeds + 240_MID_Leeds
#  + 241_MID_Leeds + 242_FWD_Leeds + 243_DEF_Leeds + 244_DEF_Leeds
#  + 245_MID_Leeds + 246_MID_Leeds + 247_MID_Leeds + 506_MID_Leeds
#  + 508_MID_Leeds <= 3
#
# _C7: 10_DEF_Arsenal + 11_FWD_Arsenal + 12_MID_Arsenal + 13_MID_Arsenal
#  + 14_DEF_Arsenal + 15_GKP_Arsenal + 16_DEF_Arsenal + 17_DEF_Arsenal
#  + 18_MID_Arsenal + 19_MID_Arsenal + 1_DEF_Arsenal + 20_DEF_Arsenal
#  + 21_MID_Arsenal + 22_MID_Arsenal + 23_MID_Arsenal + 24_GKP_Arsenal
#  + 25_MID_Arsenal + 26_DEF_Arsenal + 27_MID_Arsenal + 28_FWD_Arsenal
#  + 2_GKP_Arsenal + 3_MID_Arsenal + 4_MID_Arsenal + 5_DEF_Arsenal
#  + 6_MID_Arsenal + 7_MID_Arsenal + 8_DEF_Arsenal + 9_MID_Arsenal <= 3
#
# _C8: 349_MID_Newcastle + 350_DEF_Newcastle + 351_DEF_Newcastle
#  + 352_DEF_Newcastle + 353_GKP_Newcastle + 354_FWD_Newcastle
#  + 355_GKP_Newcastle + 356_FWD_Newcastle + 357_DEF_Newcastle
#  + 358_DEF_Newcastle + 359_MID_Newcastle + 360_DEF_Newcastle
#  + 361_FWD_Newcastle + 362_DEF_Newcastle + 363_DEF_Newcastle
#  + 364_DEF_Newcastle + 365_MID_Newcastle + 366_DEF_Newcastle
#  + 367_DEF_Newcastle + 368_MID_Newcastle + 369_MID_Newcastle
#  + 370_MID_Newcastle + 371_MID_Newcastle + 372_DEF_Newcastle
#  + 373_MID_Newcastle + 374_MID_Newcastle + 375_MID_Newcastle
#  + 376_GKP_Newcastle + 377_DEF_Newcastle <= 3
#
# _C9: 425_GKP_Spurs + 426_GKP_Spurs + 427_FWD_Spurs + 428_MID_Spurs
#  + 429_DEF_Spurs + 430_DEF_Spurs + 431_MID_Spurs + 432_DEF_Spurs
#  + 433_MID_Spurs + 434_MID_Spurs + 435_DEF_Spurs + 436_DEF_Spurs
#  + 437_MID_Spurs + 438_DEF_Spurs + 439_DEF_Spurs + 440_MID_Spurs
#  + 441_MID_Spurs + 442_DEF_Spurs + 443_DEF_Spurs + 444_MID_Spurs
#  + 445_DEF_Spurs + 446_MID_Spurs + 447_FWD_Spurs + 448_DEF_Spurs
#  + 449_MID_Spurs + 450_MID_Spurs + 451_GKP_Spurs + 452_MID_Spurs
#  + 453_FWD_Spurs + 454_FWD_Spurs + 513_DEF_Spurs <= 3
#
# _C10: 29_MID_Aston_Villa + 30_FWD_Aston_Villa + 31_GKP_Aston_Villa
#  + 32_DEF_Aston_Villa + 33_DEF_Aston_Villa + 34_MID_Aston_Villa
#  + 35_GKP_Aston_Villa + 36_MID_Aston_Villa + 37_MID_Aston_Villa
#  + 38_DEF_Aston_Villa + 39_DEF_Aston_Villa + 40_FWD_Aston_Villa
#  + 41_MID_Aston_Villa + 42_MID_Aston_Villa + 43_DEF_Aston_Villa
#  + 44_DEF_Aston_Villa + 45_MID_Aston_Villa + 46_MID_Aston_Villa
#  + 47_MID_Aston_Villa + 48_MID_Aston_Villa + 49_MID_Aston_Villa
#  + 50_DEF_Aston_Villa + 51_MID_Aston_Villa + 52_FWD_Aston_Villa
#  + 53_MID_Aston_Villa + 54_FWD_Aston_Villa + 55_MID_Aston_Villa
#  + 56_DEF_Aston_Villa <= 3
#
# _C11: 127_DEF_Chelsea + 128_DEF_Chelsea + 129_DEF_Chelsea + 130_MID_Chelsea
#  + 131_MID_Chelsea + 132_MID_Chelsea + 133_GKP_Chelsea + 134_MID_Chelsea
#  + 135_MID_Chelsea + 136_MID_Chelsea + 137_FWD_Chelsea + 138_DEF_Chelsea
#  + 139_DEF_Chelsea + 140_MID_Chelsea + 141_DEF_Chelsea + 142_MID_Chelsea
#  + 143_DEF_Chelsea + 144_MID_Chelsea + 145_FWD_Chelsea + 146_DEF_Chelsea
#  + 147_GKP_Chelsea + 148_MID_Chelsea + 149_MID_Chelsea + 150_FWD_Chelsea
#  + 151_DEF_Chelsea + 304_MID_Chelsea <= 3
#
# _C12: 176_GKP_Everton + 177_FWD_Everton + 178_DEF_Everton + 179_MID_Everton
#  + 180_DEF_Everton + 181_MID_Everton + 182_GKP_Everton + 183_MID_Everton
#  + 184_MID_Everton + 185_MID_Everton + 186_MID_Everton + 187_MID_Everton
#  + 188_DEF_Everton + 189_MID_Everton + 190_MID_Everton + 191_FWD_Everton
#  + 192_DEF_Everton + 193_DEF_Everton + 194_DEF_Everton + 195_MID_Everton
#  + 196_DEF_Everton + 197_DEF_Everton + 198_DEF_Everton + 199_DEF_Everton <= 3
#
# _C13: 248_GKP_Leicester + 249_DEF_Leicester + 250_DEF_Leicester
#  + 251_MID_Leicester + 252_MID_Leicester + 253_DEF_Leicester
#  + 254_GKP_Leicester + 255_FWD_Leicester + 256_DEF_Leicester
#  + 257_DEF_Leicester + 258_DEF_Leicester + 259_MID_Leicester
#  + 260_MID_Leicester + 261_MID_Leicester + 262_FWD_Leicester
#  + 263_MID_Leicester + 264_MID_Leicester + 265_MID_Leicester
#  + 266_MID_Leicester + 267_DEF_Leicester + 268_DEF_Leicester
#  + 269_MID_Leicester + 270_DEF_Leicester + 271_FWD_Leicester
#  + 272_DEF_Leicester + 273_DEF_Leicester <= 3
#
# _C14: 274_MID_Liverpool + 275_MID_Liverpool + 276_DEF_Liverpool
#  + 277_MID_Liverpool + 278_MID_Liverpool + 279_FWD_Liverpool
#  + 280_DEF_Liverpool + 281_GKP_Liverpool + 282_MID_Liverpool
#  + 283_MID_Liverpool + 284_DEF_Liverpool + 285_DEF_Liverpool
#  + 286_DEF_Liverpool + 287_MID_Liverpool + 288_FWD_Liverpool
#  + 289_GKP_Liverpool + 290_DEF_Liverpool + 291_MID_Liverpool
#  + 292_DEF_Liverpool + 293_MID_Liverpool + 294_MID_Liverpool
#  + 296_MID_Liverpool + 297_FWD_Liverpool + 298_DEF_Liverpool
#  + 497_GKP_Liverpool + 498_DEF_Liverpool + 499_DEF_Liverpool
#  + 500_DEF_Liverpool + 501_DEF_Liverpool <= 3
#
# _C15: 321_MID_Southampton + 400_MID_Southampton + 401_GKP_Southampton
#  + 402_MID_Southampton + 403_MID_Southampton + 404_DEF_Southampton
#  + 405_MID_Southampton + 406_MID_Southampton + 407_MID_Southampton
#  + 408_FWD_Southampton + 409_DEF_Southampton + 410_DEF_Southampton
#  + 411_FWD_Southampton + 412_MID_Southampton + 413_DEF_Southampton
#  + 414_DEF_Southampton + 415_MID_Southampton + 416_MID_Southampton
#  + 417_DEF_Southampton + 418_MID_Southampton + 419_DEF_Southampton
#  + 420_DEF_Southampton + 421_GKP_Southampton + 422_GKP_Southampton
#  + 423_DEF_Southampton + 424_GKP_Southampton + 512_MID_Southampton <= 3
#
# _C16: 455_GKP_West_Ham + 456_DEF_West_Ham + 457_DEF_West_Ham
#  + 458_FWD_West_Ham + 459_DEF_West_Ham + 460_MID_West_Ham + 461_DEF_West_Ham
#  + 462_DEF_West_Ham + 463_DEF_West_Ham + 464_MID_West_Ham + 465_MID_West_Ham
#  + 466_MID_West_Ham + 467_MID_West_Ham + 468_MID_West_Ham + 469_MID_West_Ham
#  + 470_DEF_West_Ham + 471_DEF_West_Ham + 472_DEF_West_Ham + 473_GKP_West_Ham
#  + 509_MID_West_Ham <= 3
#
# _C17: 152_GKP_Crystal_Palace + 153_DEF_Crystal_Palace + 154_MID_Crystal_Palace
#  + 155_FWD_Crystal_Palace + 156_DEF_Crystal_Palace + 157_DEF_Crystal_Palace
#  + 158_MID_Crystal_Palace + 159_MID_Crystal_Palace + 160_MID_Crystal_Palace
#  + 161_MID_Crystal_Palace + 162_GKP_Crystal_Palace + 163_MID_Crystal_Palace
#  + 164_MID_Crystal_Palace + 165_DEF_Crystal_Palace + 166_FWD_Crystal_Palace
#  + 167_DEF_Crystal_Palace + 168_FWD_Crystal_Palace + 169_MID_Crystal_Palace
#  + 170_DEF_Crystal_Palace + 171_MID_Crystal_Palace + 172_MID_Crystal_Palace
#  + 173_MID_Crystal_Palace + 174_DEF_Crystal_Palace + 175_GKP_Crystal_Palace
#  + 495_GKP_Crystal_Palace + 496_FWD_Crystal_Palace + 514_MID_Crystal_Palace
#  <= 3
#
# _C18: 101_MID_Brighton + 102_GKP_Brighton + 103_FWD_Brighton
#  + 104_MID_Brighton + 105_DEF_Brighton + 106_DEF_Brighton + 107_MID_Brighton
#  + 108_DEF_Brighton + 109_DEF_Brighton + 110_FWD_Brighton + 111_MID_Brighton
#  + 112_DEF_Brighton + 113_GKP_Brighton + 114_DEF_Brighton + 115_MID_Brighton
#  + 116_MID_Brighton + 117_MID_Brighton + 118_MID_Brighton + 119_MID_Brighton
#  + 120_MID_Brighton + 121_MID_Brighton + 122_DEF_Brighton + 123_FWD_Brighton
#  + 124_MID_Brighton + 125_FWD_Brighton + 126_MID_Brighton <= 3
#
# _C19: 474_DEF_Wolves + 475_DEF_Wolves + 476_FWD_Wolves + 477_DEF_Wolves
#  + 478_GKP_Wolves + 479_MID_Wolves + 480_MID_Wolves + 481_MID_Wolves
#  + 482_DEF_Wolves + 483_MID_Wolves + 484_DEF_Wolves + 485_MID_Wolves
#  + 486_MID_Wolves + 487_DEF_Wolves + 488_FWD_Wolves + 489_DEF_Wolves
#  + 490_MID_Wolves + 491_MID_Wolves + 492_GKP_Wolves + 493_MID_Wolves
#  + 494_DEF_Wolves + 503_MID_Wolves + 516_DEF_Wolves <= 3
#
# _C20: 299_DEF_Man_City + 300_MID_Man_City + 301_MID_Man_City
#  + 302_DEF_Man_City + 303_MID_Man_City + 305_MID_Man_City + 306_DEF_Man_City
#  + 307_GKP_Man_City + 308_DEF_Man_City + 309_DEF_Man_City + 310_GKP_Man_City
#  + 311_MID_Man_City + 312_DEF_Man_City + 313_DEF_Man_City + 314_MID_Man_City
#  + 315_MID_Man_City + 316_MID_Man_City + 317_MID_Man_City + 318_FWD_Man_City
#  + 319_FWD_Man_City + 320_DEF_Man_City + 322_DEF_Man_City + 323_FWD_Man_City
#  + 324_GKP_Man_City + 325_MID_Man_City + 502_GKP_Man_City <= 3
#
# _C21: 505_MID_Bournemouth + 57_DEF_Bournemouth + 58_MID_Bournemouth
#  + 59_DEF_Bournemouth + 60_MID_Bournemouth + 61_MID_Bournemouth
#  + 62_FWD_Bournemouth + 63_MID_Bournemouth + 64_MID_Bournemouth
#  + 65_DEF_Bournemouth + 66_FWD_Bournemouth + 67_MID_Bournemouth
#  + 68_MID_Bournemouth + 69_MID_Bournemouth + 70_MID_Bournemouth
#  + 71_DEF_Bournemouth + 72_GKP_Bournemouth + 73_DEF_Bournemouth
#  + 74_MID_Bournemouth + 75_MID_Bournemouth + 76_DEF_Bournemouth
#  + 77_GKP_Bournemouth <= 3
#
# _C22: 100_GKP_Brentford + 510_DEF_Brentford + 515_MID_Brentford
#  + 517_GKP_Brentford + 78_DEF_Brentford + 79_MID_Brentford + 80_FWD_Brentford
#  + 81_GKP_Brentford + 82_DEF_Brentford + 83_MID_Brentford + 84_DEF_Brentford
#  + 85_DEF_Brentford + 86_MID_Brentford + 87_MID_Brentford + 88_MID_Brentford
#  + 89_MID_Brentford + 90_DEF_Brentford + 91_DEF_Brentford + 92_DEF_Brentford
#  + 93_MID_Brentford + 94_MID_Brentford + 95_FWD_Brentford + 96_DEF_Brentford
#  + 97_FWD_Brentford + 98_DEF_Brentford + 99_MID_Brentford <= 3
#
# _C23: 295_DEF_Nott'm_Forest + 378_MID_Nott'm_Forest + 379_DEF_Nott'm_Forest
#  + 380_FWD_Nott'm_Forest + 381_MID_Nott'm_Forest + 382_GKP_Nott'm_Forest
#  + 383_MID_Nott'm_Forest + 384_MID_Nott'm_Forest + 385_DEF_Nott'm_Forest
#  + 386_DEF_Nott'm_Forest + 387_MID_Nott'm_Forest + 388_DEF_Nott'm_Forest
#  + 389_DEF_Nott'm_Forest + 390_MID_Nott'm_Forest + 391_FWD_Nott'm_Forest
#  + 392_DEF_Nott'm_Forest + 393_DEF_Nott'm_Forest + 394_FWD_Nott'm_Forest
#  + 395_MID_Nott'm_Forest + 396_MID_Nott'm_Forest + 397_FWD_Nott'm_Forest
#  + 398_GKP_Nott'm_Forest + 399_DEF_Nott'm_Forest + 507_DEF_Nott'm_Forest
#  + 511_DEF_Nott'm_Forest + 518_GKP_Nott'm_Forest <= 3
#
# _C24: 200_MID_Fulham + 201_DEF_Fulham + 202_MID_Fulham + 203_MID_Fulham
#  + 204_MID_Fulham + 205_MID_Fulham + 206_DEF_Fulham + 207_GKP_Fulham
#  + 208_DEF_Fulham + 209_DEF_Fulham + 210_FWD_Fulham + 211_MID_Fulham
#  + 212_MID_Fulham + 213_GKP_Fulham + 214_MID_Fulham + 215_DEF_Fulham
#  + 216_MID_Fulham + 217_DEF_Fulham + 218_FWD_Fulham + 219_FWD_Fulham
#  + 220_MID_Fulham + 346_MID_Fulham <= 3
#
# _C25: 326_FWD_Man_Utd + 327_GKP_Man_Utd + 328_DEF_Man_Utd + 329_DEF_Man_Utd
#  + 330_DEF_Man_Utd + 331_MID_Man_Utd + 332_DEF_Man_Utd + 333_MID_Man_Utd
#  + 334_DEF_Man_Utd + 335_MID_Man_Utd + 336_MID_Man_Utd + 337_DEF_Man_Utd
#  + 338_MID_Man_Utd + 339_DEF_Man_Utd + 340_MID_Man_Utd + 341_DEF_Man_Utd
#  + 342_DEF_Man_Utd + 343_DEF_Man_Utd + 344_MID_Man_Utd + 345_FWD_Man_Utd
#  + 347_MID_Man_Utd + 348_GKP_Man_Utd + 504_DEF_Man_Utd + 519_MID_Man_Utd >= 1
#
# _C26: 455_GKP_West_Ham + 456_DEF_West_Ham + 457_DEF_West_Ham
#  + 458_FWD_West_Ham + 459_DEF_West_Ham + 460_MID_West_Ham + 461_DEF_West_Ham
#  + 462_DEF_West_Ham + 463_DEF_West_Ham + 464_MID_West_Ham + 465_MID_West_Ham
#  + 466_MID_West_Ham + 467_MID_West_Ham + 468_MID_West_Ham + 469_MID_West_Ham
#  + 470_DEF_West_Ham + 471_DEF_West_Ham + 472_DEF_West_Ham + 473_GKP_West_Ham
#  + 509_MID_West_Ham = 0
#
# _C27: 40 100_GKP_Brentford + 50 101_MID_Brighton + 40 102_GKP_Brighton
#  + 65 103_FWD_Brighton + 55 104_MID_Brighton + 45 105_DEF_Brighton
#  + 45 106_DEF_Brighton + 50 107_MID_Brighton + 45 108_DEF_Brighton
#  + 45 109_DEF_Brighton + 45 10_DEF_Arsenal + 65 110_FWD_Brighton
#  + 65 111_MID_Brighton + 50 112_DEF_Brighton + 45 113_GKP_Brighton
#  + 45 114_DEF_Brighton + 45 115_MID_Brighton + 55 116_MID_Brighton
#  + 45 117_MID_Brighton + 55 118_MID_Brighton + 45 119_MID_Brighton
#  + 70 11_FWD_Arsenal + 50 120_MID_Brighton + 45 121_MID_Brighton
#  + 40 122_DEF_Brighton + 55 123_FWD_Brighton + 50 124_MID_Brighton
#  + 50 125_FWD_Brighton + 45 126_MID_Brighton + 50 127_DEF_Chelsea
#  + 55 128_DEF_Chelsea + 55 129_DEF_Chelsea + 60 12_MID_Arsenal
#  + 60 130_MID_Chelsea + 50 131_MID_Chelsea + 50 132_MID_Chelsea
#  + 45 133_GKP_Chelsea + 50 134_MID_Chelsea + 60 135_MID_Chelsea
#  + 50 136_MID_Chelsea + 80 137_FWD_Chelsea + 40 138_DEF_Chelsea
#  + 60 139_DEF_Chelsea + 80 13_MID_Arsenal + 60 140_MID_Chelsea
#  + 50 141_DEF_Chelsea + 80 142_MID_Chelsea + 50 143_DEF_Chelsea
#  + 55 144_MID_Chelsea + 80 145_FWD_Chelsea + 60 146_DEF_Chelsea
#  + 50 147_GKP_Chelsea + 60 148_MID_Chelsea + 45 149_MID_Chelsea
#  + 45 14_DEF_Arsenal + 55 150_FWD_Chelsea + 45 151_DEF_Chelsea
#  + 45 152_GKP_Crystal_Palace + 40 153_DEF_Crystal_Palace
#  + 50 154_MID_Crystal_Palace + 55 155_FWD_Crystal_Palace
#  + 45 156_DEF_Crystal_Palace + 45 157_DEF_Crystal_Palace
#  + 45 158_MID_Crystal_Palace + 55 159_MID_Crystal_Palace + 50 15_GKP_Arsenal
#  + 70 160_MID_Crystal_Palace + 50 161_MID_Crystal_Palace
#  + 45 162_GKP_Crystal_Palace + 50 163_MID_Crystal_Palace
#  + 45 164_MID_Crystal_Palace + 45 165_DEF_Crystal_Palace
#  + 55 166_FWD_Crystal_Palace + 45 167_DEF_Crystal_Palace
#  + 55 168_FWD_Crystal_Palace + 55 169_MID_Crystal_Palace + 50 16_DEF_Arsenal
#  + 45 170_DEF_Crystal_Palace + 55 171_MID_Crystal_Palace
#  + 45 172_MID_Crystal_Palace + 45 173_MID_Crystal_Palace
#  + 40 174_DEF_Crystal_Palace + 45 175_GKP_Crystal_Palace + 40 176_GKP_Everton
#  + 50 177_FWD_Everton + 45 178_DEF_Everton + 55 179_MID_Everton
#  + 45 17_DEF_Arsenal + 45 180_DEF_Everton + 55 181_MID_Everton
#  + 45 182_GKP_Everton + 50 183_MID_Everton + 45 184_MID_Everton
#  + 55 185_MID_Everton + 55 186_MID_Everton + 45 187_MID_Everton
#  + 45 188_DEF_Everton + 55 189_MID_Everton + 45 18_MID_Arsenal
#  + 50 190_MID_Everton + 80 191_FWD_Everton + 45 192_DEF_Everton
#  + 45 193_DEF_Everton + 45 194_DEF_Everton + 55 195_MID_Everton
#  + 40 196_DEF_Everton + 40 197_DEF_Everton + 40 198_DEF_Everton
#  + 45 199_DEF_Everton + 60 19_MID_Arsenal + 45 1_DEF_Arsenal
#  + 50 200_MID_Fulham + 45 201_DEF_Fulham + 50 202_MID_Fulham
#  + 45 203_MID_Fulham + 55 204_MID_Fulham + 55 205_MID_Fulham
#  + 45 206_DEF_Fulham + 40 207_GKP_Fulham + 40 208_DEF_Fulham
#  + 45 209_DEF_Fulham + 45 20_DEF_Arsenal + 65 210_FWD_Fulham
#  + 45 211_MID_Fulham + 60 212_MID_Fulham + 45 213_GKP_Fulham
#  + 50 214_MID_Fulham + 45 215_DEF_Fulham + 45 216_MID_Fulham
#  + 45 217_DEF_Fulham + 55 218_FWD_Fulham + 45 219_FWD_Fulham
#  + 50 21_MID_Arsenal + 50 220_MID_Fulham + 45 221_DEF_Leeds + 45 222_DEF_Leeds
#  + 50 223_MID_Leeds + 45 224_MID_Leeds + 60 225_MID_Leeds + 50 226_DEF_Leeds
#  + 75 227_FWD_Leeds + 45 228_DEF_Leeds + 50 229_MID_Leeds + 45 22_MID_Arsenal
#  + 45 230_DEF_Leeds + 60 231_MID_Leeds + 70 232_MID_Leeds + 60 233_MID_Leeds
#  + 45 234_MID_Leeds + 45 235_DEF_Leeds + 40 236_GKP_Leeds + 45 237_FWD_Leeds
#  + 45 238_GKP_Leeds + 45 239_DEF_Leeds + 50 23_MID_Arsenal + 45 240_MID_Leeds
#  + 45 241_MID_Leeds + 55 242_FWD_Leeds + 40 243_DEF_Leeds + 50 244_DEF_Leeds
#  + 50 245_MID_Leeds + 55 246_MID_Leeds + 45 247_MID_Leeds
#  + 50 248_GKP_Leicester + 45 249_DEF_Leicester + 40 24_GKP_Arsenal
#  + 40 250_DEF_Leicester + 50 251_MID_Leicester + 45 252_MID_Leicester
#  + 40 253_DEF_Leicester + 40 254_GKP_Leicester + 95 255_FWD_Leicester
#  + 45 256_DEF_Leicester + 45 257_DEF_Leicester + 45 258_DEF_Leicester
#  + 65 259_MID_Leicester + 60 25_MID_Arsenal + 50 260_MID_Leicester
#  + 80 261_MID_Leicester + 65 262_FWD_Leicester + 45 263_MID_Leicester
#  + 70 264_MID_Leicester + 50 265_MID_Leicester + 50 266_MID_Leicester
#  + 45 267_DEF_Leicester + 45 268_DEF_Leicester + 45 269_MID_Leicester
#  + 45 26_DEF_Arsenal + 45 270_DEF_Leicester + 60 271_FWD_Leicester
#  + 45 272_DEF_Leicester + 40 273_DEF_Leicester + 45 274_MID_Liverpool
#  + 55 275_MID_Liverpool + 60 276_DEF_Liverpool + 55 277_MID_Liverpool
#  + 50 278_MID_Liverpool + 80 279_FWD_Liverpool + 50 27_MID_Arsenal
#  + 65 280_DEF_Liverpool + 55 281_GKP_Liverpool + 55 282_MID_Liverpool
#  + 130 283_MID_Liverpool + 70 284_DEF_Liverpool + 75 285_DEF_Liverpool
#  + 45 286_DEF_Liverpool + 50 287_MID_Liverpool + 90 288_FWD_Liverpool
#  + 40 289_GKP_Liverpool + 80 28_FWD_Arsenal + 50 290_DEF_Liverpool
#  + 50 291_MID_Liverpool + 45 292_DEF_Liverpool + 80 293_MID_Liverpool
#  + 50 294_MID_Liverpool + 40 295_DEF_Nott'm_Forest + 55 296_MID_Liverpool
#  + 90 297_FWD_Liverpool + 40 298_DEF_Liverpool + 50 299_DEF_Man_City
#  + 70 29_MID_Aston_Villa + 45 2_GKP_Arsenal + 75 300_MID_Man_City
#  + 120 301_MID_Man_City + 55 302_DEF_Man_City + 80 303_MID_Man_City
#  + 100 304_MID_Chelsea + 70 305_MID_Man_City + 70 306_DEF_Man_City
#  + 55 307_GKP_Man_City + 50 308_DEF_Man_City + 60 309_DEF_Man_City
#  + 70 30_FWD_Aston_Villa + 40 310_GKP_Man_City + 70 311_MID_Man_City
#  + 60 312_DEF_Man_City + 50 313_DEF_Man_City + 80 314_MID_Man_City
#  + 60 315_MID_Man_City + 45 316_MID_Man_City + 45 317_MID_Man_City
#  + 115 318_FWD_Man_City + 65 319_FWD_Man_City + 50 31_GKP_Aston_Villa
#  + 40 320_DEF_Man_City + 45 321_MID_Southampton + 40 322_DEF_Man_City
#  + 45 323_FWD_Man_City + 40 324_GKP_Man_City + 50 325_MID_Man_City
#  + 105 326_FWD_Man_Utd + 50 327_GKP_Man_Utd + 40 328_DEF_Man_Utd
#  + 50 329_DEF_Man_Utd + 45 32_DEF_Aston_Villa + 50 330_DEF_Man_Utd
#  + 55 331_MID_Man_Utd + 50 332_DEF_Man_Utd + 100 333_MID_Man_Utd
#  + 50 334_DEF_Man_Utd + 65 335_MID_Man_Utd + 55 336_MID_Man_Utd
#  + 45 337_DEF_Man_Utd + 50 338_MID_Man_Utd + 40 339_DEF_Man_Utd
#  + 50 33_DEF_Aston_Villa + 75 340_MID_Man_Utd + 45 341_DEF_Man_Utd
#  + 45 342_DEF_Man_Utd + 40 343_DEF_Man_Utd + 50 344_MID_Man_Utd
#  + 70 345_FWD_Man_Utd + 45 346_MID_Fulham + 45 347_MID_Man_Utd
#  + 40 348_GKP_Man_Utd + 50 349_MID_Newcastle + 50 34_MID_Aston_Villa
#  + 45 350_DEF_Newcastle + 45 351_DEF_Newcastle + 45 352_DEF_Newcastle
#  + 40 353_GKP_Newcastle + 60 354_FWD_Newcastle + 45 355_GKP_Newcastle
#  + 75 356_FWD_Newcastle + 50 357_DEF_Newcastle + 45 358_DEF_Newcastle
#  + 55 359_MID_Newcastle + 40 35_GKP_Aston_Villa + 45 360_DEF_Newcastle
#  + 45 361_FWD_Newcastle + 40 362_DEF_Newcastle + 45 363_DEF_Newcastle
#  + 45 364_DEF_Newcastle + 45 365_MID_Newcastle + 45 366_DEF_Newcastle
#  + 50 367_DEF_Newcastle + 65 368_MID_Newcastle + 50 369_MID_Newcastle
#  + 45 36_MID_Aston_Villa + 45 370_MID_Newcastle + 60 371_MID_Newcastle
#  + 45 372_DEF_Newcastle + 50 373_MID_Newcastle + 60 374_MID_Newcastle
#  + 45 375_MID_Newcastle + 50 376_GKP_Newcastle + 45 377_DEF_Newcastle
#  + 45 378_MID_Nott'm_Forest + 45 379_DEF_Nott'm_Forest + 55 37_MID_Aston_Villa
#  + 45 380_FWD_Nott'm_Forest + 45 381_MID_Nott'm_Forest
#  + 45 382_GKP_Nott'm_Forest + 45 383_MID_Nott'm_Forest
#  + 50 384_MID_Nott'm_Forest + 45 385_DEF_Nott'm_Forest
#  + 40 386_DEF_Nott'm_Forest + 50 387_MID_Nott'm_Forest
#  + 45 388_DEF_Nott'm_Forest + 40 389_DEF_Nott'm_Forest + 45 38_DEF_Aston_Villa
#  + 50 390_MID_Nott'm_Forest + 50 391_FWD_Nott'm_Forest
#  + 45 392_DEF_Nott'm_Forest + 45 393_DEF_Nott'm_Forest
#  + 60 394_FWD_Nott'm_Forest + 50 395_MID_Nott'm_Forest
#  + 45 396_MID_Nott'm_Forest + 60 397_FWD_Nott'm_Forest
#  + 45 398_GKP_Nott'm_Forest + 45 399_DEF_Nott'm_Forest + 45 39_DEF_Aston_Villa
#  + 50 3_MID_Arsenal + 50 400_MID_Southampton + 45 401_GKP_Southampton
#  + 50 402_MID_Southampton + 55 403_MID_Southampton + 45 404_DEF_Southampton
#  + 50 405_MID_Southampton + 55 406_MID_Southampton + 65 407_MID_Southampton
#  + 55 408_FWD_Southampton + 45 409_DEF_Southampton + 75 40_FWD_Aston_Villa
#  + 45 410_DEF_Southampton + 65 411_FWD_Southampton + 50 412_MID_Southampton
#  + 45 413_DEF_Southampton + 40 414_DEF_Southampton + 45 415_MID_Southampton
#  + 45 416_MID_Southampton + 45 417_DEF_Southampton + 50 418_MID_Southampton
#  + 45 419_DEF_Southampton + 45 41_MID_Aston_Villa + 45 420_DEF_Southampton
#  + 40 421_GKP_Southampton + 45 422_GKP_Southampton + 45 423_DEF_Southampton
#  + 40 424_GKP_Southampton + 55 425_GKP_Spurs + 40 426_GKP_Spurs
#  + 115 427_FWD_Spurs + 120 428_MID_Spurs + 50 429_DEF_Spurs
#  + 60 42_MID_Aston_Villa + 50 430_DEF_Spurs + 60 431_MID_Spurs
#  + 50 432_DEF_Spurs + 55 433_MID_Spurs + 45 434_MID_Spurs + 45 435_DEF_Spurs
#  + 45 436_DEF_Spurs + 55 437_MID_Spurs + 45 438_DEF_Spurs + 40 439_DEF_Spurs
#  + 50 43_DEF_Aston_Villa + 55 440_MID_Spurs + 45 441_MID_Spurs
#  + 40 442_DEF_Spurs + 50 443_DEF_Spurs + 50 444_MID_Spurs + 50 445_DEF_Spurs
#  + 80 446_MID_Spurs + 45 447_FWD_Spurs + 55 448_DEF_Spurs + 45 449_MID_Spurs
#  + 45 44_DEF_Aston_Villa + 45 450_MID_Spurs + 40 451_GKP_Spurs
#  + 45 452_MID_Spurs + 45 453_FWD_Spurs + 85 454_FWD_Spurs
#  + 50 455_GKP_West_Ham + 45 456_DEF_West_Ham + 50 457_DEF_West_Ham
#  + 75 458_FWD_West_Ham + 50 459_DEF_West_Ham + 50 45_MID_Aston_Villa
#  + 55 460_MID_West_Ham + 45 461_DEF_West_Ham + 45 462_DEF_West_Ham
#  + 45 463_DEF_West_Ham + 60 464_MID_West_Ham + 85 465_MID_West_Ham
#  + 50 466_MID_West_Ham + 50 467_MID_West_Ham + 55 468_MID_West_Ham
#  + 55 469_MID_West_Ham + 50 46_MID_Aston_Villa + 45 470_DEF_West_Ham
#  + 45 471_DEF_West_Ham + 50 472_DEF_West_Ham + 45 473_GKP_West_Ham
#  + 45 474_DEF_Wolves + 50 475_DEF_Wolves + 70 476_FWD_Wolves
#  + 45 477_DEF_Wolves + 50 478_GKP_Wolves + 50 479_MID_Wolves
#  + 55 47_MID_Aston_Villa + 55 480_MID_Wolves + 60 481_MID_Wolves
#  + 50 482_DEF_Wolves + 55 483_MID_Wolves + 45 484_DEF_Wolves
#  + 45 485_MID_Wolves + 55 486_MID_Wolves + 45 487_DEF_Wolves
#  + 55 488_FWD_Wolves + 40 489_DEF_Wolves + 45 48_MID_Aston_Villa
#  + 50 490_MID_Wolves + 55 491_MID_Wolves + 40 492_GKP_Wolves
#  + 55 493_MID_Wolves + 40 494_DEF_Wolves + 40 495_GKP_Crystal_Palace
#  + 45 496_FWD_Crystal_Palace + 40 497_GKP_Liverpool + 40 498_DEF_Liverpool
#  + 40 499_DEF_Liverpool + 45 49_MID_Aston_Villa + 45 4_MID_Arsenal
#  + 40 500_DEF_Liverpool + 40 501_DEF_Liverpool + 40 502_GKP_Man_City
#  + 50 503_MID_Wolves + 45 504_DEF_Man_Utd + 50 505_MID_Bournemouth
#  + 50 506_MID_Leeds + 45 507_DEF_Nott'm_Forest + 65 508_MID_Leeds
#  + 45 509_MID_West_Ham + 50 50_DEF_Aston_Villa + 50 510_DEF_Brentford
#  + 45 511_DEF_Nott'm_Forest + 55 512_MID_Southampton + 50 513_DEF_Spurs
#  + 50 514_MID_Crystal_Palace + 55 515_MID_Brentford + 45 516_DEF_Wolves
#  + 45 517_GKP_Brentford + 40 518_GKP_Nott'm_Forest + 65 519_MID_Man_Utd
#  + 50 51_MID_Aston_Villa + 55 52_FWD_Aston_Villa + 50 53_MID_Aston_Villa
#  + 45 54_FWD_Aston_Villa + 45 55_MID_Aston_Villa + 40 56_DEF_Aston_Villa
#  + 45 57_DEF_Bournemouth + 50 58_MID_Bournemouth + 45 59_DEF_Bournemouth
#  + 45 5_DEF_Arsenal + 55 60_MID_Bournemouth + 55 61_MID_Bournemouth
#  + 55 62_FWD_Bournemouth + 50 63_MID_Bournemouth + 50 64_MID_Bournemouth
#  + 45 65_DEF_Bournemouth + 60 66_FWD_Bournemouth + 50 67_MID_Bournemouth
#  + 45 68_MID_Bournemouth + 55 69_MID_Bournemouth + 50 6_MID_Arsenal
#  + 55 70_MID_Bournemouth + 45 71_DEF_Bournemouth + 45 72_GKP_Bournemouth
#  + 45 73_DEF_Bournemouth + 50 74_MID_Bournemouth + 55 75_MID_Bournemouth
#  + 45 76_DEF_Bournemouth + 40 77_GKP_Bournemouth + 45 78_DEF_Brentford
#  + 55 79_MID_Brentford + 65 7_MID_Arsenal + 70 80_FWD_Brentford
#  + 45 81_GKP_Brentford + 50 82_DEF_Brentford + 45 83_MID_Brentford
#  + 45 84_DEF_Brentford + 45 85_DEF_Brentford + 55 86_MID_Brentford
#  + 50 87_MID_Brentford + 50 88_MID_Brentford + 55 89_MID_Brentford
#  + 50 8_DEF_Arsenal + 45 90_DEF_Brentford + 45 91_DEF_Brentford
#  + 45 92_DEF_Brentford + 50 93_MID_Brentford + 45 94_MID_Brentford
#  + 60 95_FWD_Brentford + 40 96_DEF_Brentford + 45 97_FWD_Brentford
#  + 40 98_DEF_Brentford + 45 99_MID_Brentford + 55 9_MID_Arsenal <= 970
#
# _C28: 100_GKP_Brentford + 101_MID_Brighton + 102_GKP_Brighton
#  + 103_FWD_Brighton + 104_MID_Brighton + 105_DEF_Brighton + 106_DEF_Brighton
#  + 107_MID_Brighton + 108_DEF_Brighton + 109_DEF_Brighton + 10_DEF_Arsenal
#  + 110_FWD_Brighton + 111_MID_Brighton + 112_DEF_Brighton + 113_GKP_Brighton
#  + 114_DEF_Brighton + 115_MID_Brighton + 116_MID_Brighton + 117_MID_Brighton
#  + 118_MID_Brighton + 119_MID_Brighton + 11_FWD_Arsenal + 120_MID_Brighton
#  + 121_MID_Brighton + 122_DEF_Brighton + 123_FWD_Brighton + 124_MID_Brighton
#  + 125_FWD_Brighton + 126_MID_Brighton + 127_DEF_Chelsea + 128_DEF_Chelsea
#  + 129_DEF_Chelsea + 12_MID_Arsenal + 130_MID_Chelsea + 131_MID_Chelsea
#  + 132_MID_Chelsea + 133_GKP_Chelsea + 134_MID_Chelsea + 135_MID_Chelsea
#  + 136_MID_Chelsea + 137_FWD_Chelsea + 138_DEF_Chelsea + 139_DEF_Chelsea
#  + 13_MID_Arsenal + 140_MID_Chelsea + 141_DEF_Chelsea + 142_MID_Chelsea
#  + 143_DEF_Chelsea + 144_MID_Chelsea + 145_FWD_Chelsea + 146_DEF_Chelsea
#  + 147_GKP_Chelsea + 148_MID_Chelsea + 149_MID_Chelsea + 14_DEF_Arsenal
#  + 150_FWD_Chelsea + 151_DEF_Chelsea + 152_GKP_Crystal_Palace
#  + 153_DEF_Crystal_Palace + 154_MID_Crystal_Palace + 155_FWD_Crystal_Palace
#  + 156_DEF_Crystal_Palace + 157_DEF_Crystal_Palace + 158_MID_Crystal_Palace
#  + 159_MID_Crystal_Palace + 15_GKP_Arsenal + 160_MID_Crystal_Palace
#  + 161_MID_Crystal_Palace + 162_GKP_Crystal_Palace + 163_MID_Crystal_Palace
#  + 164_MID_Crystal_Palace + 165_DEF_Crystal_Palace + 166_FWD_Crystal_Palace
#  + 167_DEF_Crystal_Palace + 168_FWD_Crystal_Palace + 169_MID_Crystal_Palace
#  + 16_DEF_Arsenal + 170_DEF_Crystal_Palace + 171_MID_Crystal_Palace
#  + 172_MID_Crystal_Palace + 173_MID_Crystal_Palace + 174_DEF_Crystal_Palace
#  + 175_GKP_Crystal_Palace + 176_GKP_Everton + 177_FWD_Everton
#  + 178_DEF_Everton + 179_MID_Everton + 17_DEF_Arsenal + 180_DEF_Everton
#  + 181_MID_Everton + 182_GKP_Everton + 183_MID_Everton + 184_MID_Everton
#  + 185_MID_Everton + 186_MID_Everton + 187_MID_Everton + 188_DEF_Everton
#  + 189_MID_Everton + 18_MID_Arsenal + 190_MID_Everton + 191_FWD_Everton
#  + 192_DEF_Everton + 193_DEF_Everton + 194_DEF_Everton + 195_MID_Everton
#  + 196_DEF_Everton + 197_DEF_Everton + 198_DEF_Everton + 199_DEF_Everton
#  + 19_MID_Arsenal + 1_DEF_Arsenal + 200_MID_Fulham + 201_DEF_Fulham
#  + 202_MID_Fulham + 203_MID_Fulham + 204_MID_Fulham + 205_MID_Fulham
#  + 206_DEF_Fulham + 207_GKP_Fulham + 208_DEF_Fulham + 209_DEF_Fulham
#  + 20_DEF_Arsenal + 210_FWD_Fulham + 211_MID_Fulham + 212_MID_Fulham
#  + 213_GKP_Fulham + 214_MID_Fulham + 215_DEF_Fulham + 216_MID_Fulham
#  + 217_DEF_Fulham + 218_FWD_Fulham + 219_FWD_Fulham + 21_MID_Arsenal
#  + 220_MID_Fulham + 221_DEF_Leeds + 222_DEF_Leeds + 223_MID_Leeds
#  + 224_MID_Leeds + 225_MID_Leeds + 226_DEF_Leeds + 227_FWD_Leeds
#  + 228_DEF_Leeds + 229_MID_Leeds + 22_MID_Arsenal + 230_DEF_Leeds
#  + 231_MID_Leeds + 232_MID_Leeds + 233_MID_Leeds + 234_MID_Leeds
#  + 235_DEF_Leeds + 236_GKP_Leeds + 237_FWD_Leeds + 238_GKP_Leeds
#  + 239_DEF_Leeds + 23_MID_Arsenal + 240_MID_Leeds + 241_MID_Leeds
#  + 242_FWD_Leeds + 243_DEF_Leeds + 244_DEF_Leeds + 245_MID_Leeds
#  + 246_MID_Leeds + 247_MID_Leeds + 248_GKP_Leicester + 249_DEF_Leicester
#  + 24_GKP_Arsenal + 250_DEF_Leicester + 251_MID_Leicester + 252_MID_Leicester
#  + 253_DEF_Leicester + 254_GKP_Leicester + 255_FWD_Leicester
#  + 256_DEF_Leicester + 257_DEF_Leicester + 258_DEF_Leicester
#  + 259_MID_Leicester + 25_MID_Arsenal + 260_MID_Leicester + 261_MID_Leicester
#  + 262_FWD_Leicester + 263_MID_Leicester + 264_MID_Leicester
#  + 265_MID_Leicester + 266_MID_Leicester + 267_DEF_Leicester
#  + 268_DEF_Leicester + 269_MID_Leicester + 26_DEF_Arsenal + 270_DEF_Leicester
#  + 271_FWD_Leicester + 272_DEF_Leicester + 273_DEF_Leicester
#  + 274_MID_Liverpool + 275_MID_Liverpool + 276_DEF_Liverpool
#  + 277_MID_Liverpool + 278_MID_Liverpool + 279_FWD_Liverpool + 27_MID_Arsenal
#  + 280_DEF_Liverpool + 281_GKP_Liverpool + 282_MID_Liverpool
#  + 283_MID_Liverpool + 284_DEF_Liverpool + 285_DEF_Liverpool
#  + 286_DEF_Liverpool + 287_MID_Liverpool + 288_FWD_Liverpool
#  + 289_GKP_Liverpool + 28_FWD_Arsenal + 290_DEF_Liverpool + 291_MID_Liverpool
#  + 292_DEF_Liverpool + 293_MID_Liverpool + 294_MID_Liverpool
#  + 295_DEF_Nott'm_Forest + 296_MID_Liverpool + 297_FWD_Liverpool
#  + 298_DEF_Liverpool + 299_DEF_Man_City + 29_MID_Aston_Villa + 2_GKP_Arsenal
#  + 300_MID_Man_City + 301_MID_Man_City + 302_DEF_Man_City + 303_MID_Man_City
#  + 304_MID_Chelsea + 305_MID_Man_City + 306_DEF_Man_City + 307_GKP_Man_City
#  + 308_DEF_Man_City + 309_DEF_Man_City + 30_FWD_Aston_Villa + 310_GKP_Man_City
#  + 311_MID_Man_City + 312_DEF_Man_City + 313_DEF_Man_City + 314_MID_Man_City
#  + 315_MID_Man_City + 316_MID_Man_City + 317_MID_Man_City + 318_FWD_Man_City
#  + 319_FWD_Man_City + 31_GKP_Aston_Villa + 320_DEF_Man_City
#  + 321_MID_Southampton + 322_DEF_Man_City + 323_FWD_Man_City
#  + 324_GKP_Man_City + 325_MID_Man_City + 326_FWD_Man_Utd + 327_GKP_Man_Utd
#  + 328_DEF_Man_Utd + 329_DEF_Man_Utd + 32_DEF_Aston_Villa + 330_DEF_Man_Utd
#  + 331_MID_Man_Utd + 332_DEF_Man_Utd + 333_MID_Man_Utd + 334_DEF_Man_Utd
#  + 335_MID_Man_Utd + 336_MID_Man_Utd + 337_DEF_Man_Utd + 338_MID_Man_Utd
#  + 339_DEF_Man_Utd + 33_DEF_Aston_Villa + 340_MID_Man_Utd + 341_DEF_Man_Utd
#  + 342_DEF_Man_Utd + 343_DEF_Man_Utd + 344_MID_Man_Utd + 345_FWD_Man_Utd
#  + 346_MID_Fulham + 347_MID_Man_Utd + 348_GKP_Man_Utd + 349_MID_Newcastle
#  + 34_MID_Aston_Villa + 350_DEF_Newcastle + 351_DEF_Newcastle
#  + 352_DEF_Newcastle + 353_GKP_Newcastle + 354_FWD_Newcastle
#  + 355_GKP_Newcastle + 356_FWD_Newcastle + 357_DEF_Newcastle
#  + 358_DEF_Newcastle + 359_MID_Newcastle + 35_GKP_Aston_Villa
#  + 360_DEF_Newcastle + 361_FWD_Newcastle + 362_DEF_Newcastle
#  + 363_DEF_Newcastle + 364_DEF_Newcastle + 365_MID_Newcastle
#  + 366_DEF_Newcastle + 367_DEF_Newcastle + 368_MID_Newcastle
#  + 369_MID_Newcastle + 36_MID_Aston_Villa + 370_MID_Newcastle
#  + 371_MID_Newcastle + 372_DEF_Newcastle + 373_MID_Newcastle
#  + 374_MID_Newcastle + 375_MID_Newcastle + 376_GKP_Newcastle
#  + 377_DEF_Newcastle + 378_MID_Nott'm_Forest + 379_DEF_Nott'm_Forest
#  + 37_MID_Aston_Villa + 380_FWD_Nott'm_Forest + 381_MID_Nott'm_Forest
#  + 382_GKP_Nott'm_Forest + 383_MID_Nott'm_Forest + 384_MID_Nott'm_Forest
#  + 385_DEF_Nott'm_Forest + 386_DEF_Nott'm_Forest + 387_MID_Nott'm_Forest
#  + 388_DEF_Nott'm_Forest + 389_DEF_Nott'm_Forest + 38_DEF_Aston_Villa
#  + 390_MID_Nott'm_Forest + 391_FWD_Nott'm_Forest + 392_DEF_Nott'm_Forest
#  + 393_DEF_Nott'm_Forest + 394_FWD_Nott'm_Forest + 395_MID_Nott'm_Forest
#  + 396_MID_Nott'm_Forest + 397_FWD_Nott'm_Forest + 398_GKP_Nott'm_Forest
#  + 399_DEF_Nott'm_Forest + 39_DEF_Aston_Villa + 3_MID_Arsenal
#  + 400_MID_Southampton + 401_GKP_Southampton + 402_MID_Southampton
#  + 403_MID_Southampton + 404_DEF_Southampton + 405_MID_Southampton
#  + 406_MID_Southampton + 407_MID_Southampton + 408_FWD_Southampton
#  + 409_DEF_Southampton + 40_FWD_Aston_Villa + 410_DEF_Southampton
#  + 411_FWD_Southampton + 412_MID_Southampton + 413_DEF_Southampton
#  + 414_DEF_Southampton + 415_MID_Southampton + 416_MID_Southampton
#  + 417_DEF_Southampton + 418_MID_Southampton + 419_DEF_Southampton
#  + 41_MID_Aston_Villa + 420_DEF_Southampton + 421_GKP_Southampton
#  + 422_GKP_Southampton + 423_DEF_Southampton + 424_GKP_Southampton
#  + 425_GKP_Spurs + 426_GKP_Spurs + 427_FWD_Spurs + 428_MID_Spurs
#  + 429_DEF_Spurs + 42_MID_Aston_Villa + 430_DEF_Spurs + 431_MID_Spurs
#  + 432_DEF_Spurs + 433_MID_Spurs + 434_MID_Spurs + 435_DEF_Spurs
#  + 436_DEF_Spurs + 437_MID_Spurs + 438_DEF_Spurs + 439_DEF_Spurs
#  + 43_DEF_Aston_Villa + 440_MID_Spurs + 441_MID_Spurs + 442_DEF_Spurs
#  + 443_DEF_Spurs + 444_MID_Spurs + 445_DEF_Spurs + 446_MID_Spurs
#  + 447_FWD_Spurs + 448_DEF_Spurs + 449_MID_Spurs + 44_DEF_Aston_Villa
#  + 450_MID_Spurs + 451_GKP_Spurs + 452_MID_Spurs + 453_FWD_Spurs
#  + 454_FWD_Spurs + 455_GKP_West_Ham + 456_DEF_West_Ham + 457_DEF_West_Ham
#  + 458_FWD_West_Ham + 459_DEF_West_Ham + 45_MID_Aston_Villa + 460_MID_West_Ham
#  + 461_DEF_West_Ham + 462_DEF_West_Ham + 463_DEF_West_Ham + 464_MID_West_Ham
#  + 465_MID_West_Ham + 466_MID_West_Ham + 467_MID_West_Ham + 468_MID_West_Ham
#  + 469_MID_West_Ham + 46_MID_Aston_Villa + 470_DEF_West_Ham + 471_DEF_West_Ham
#  + 472_DEF_West_Ham + 473_GKP_West_Ham + 474_DEF_Wolves + 475_DEF_Wolves
#  + 476_FWD_Wolves + 477_DEF_Wolves + 478_GKP_Wolves + 479_MID_Wolves
#  + 47_MID_Aston_Villa + 480_MID_Wolves + 481_MID_Wolves + 482_DEF_Wolves
#  + 483_MID_Wolves + 484_DEF_Wolves + 485_MID_Wolves + 486_MID_Wolves
#  + 487_DEF_Wolves + 488_FWD_Wolves + 489_DEF_Wolves + 48_MID_Aston_Villa
#  + 490_MID_Wolves + 491_MID_Wolves + 492_GKP_Wolves + 493_MID_Wolves
#  + 494_DEF_Wolves + 495_GKP_Crystal_Palace + 496_FWD_Crystal_Palace
#  + 497_GKP_Liverpool + 498_DEF_Liverpool + 499_DEF_Liverpool
#  + 49_MID_Aston_Villa + 4_MID_Arsenal + 500_DEF_Liverpool + 501_DEF_Liverpool
#  + 502_GKP_Man_City + 503_MID_Wolves + 504_DEF_Man_Utd + 505_MID_Bournemouth
#  + 506_MID_Leeds + 507_DEF_Nott'm_Forest + 508_MID_Leeds + 509_MID_West_Ham
#  + 50_DEF_Aston_Villa + 510_DEF_Brentford + 511_DEF_Nott'm_Forest
#  + 512_MID_Southampton + 513_DEF_Spurs + 514_MID_Crystal_Palace
#  + 515_MID_Brentford + 516_DEF_Wolves + 517_GKP_Brentford
#  + 518_GKP_Nott'm_Forest + 519_MID_Man_Utd + 51_MID_Aston_Villa
#  + 52_FWD_Aston_Villa + 53_MID_Aston_Villa + 54_FWD_Aston_Villa
#  + 55_MID_Aston_Villa + 56_DEF_Aston_Villa + 57_DEF_Bournemouth
#  + 58_MID_Bournemouth + 59_DEF_Bournemouth + 5_DEF_Arsenal
#  + 60_MID_Bournemouth + 61_MID_Bournemouth + 62_FWD_Bournemouth
#  + 63_MID_Bournemouth + 64_MID_Bournemouth + 65_DEF_Bournemouth
#  + 66_FWD_Bournemouth + 67_MID_Bournemouth + 68_MID_Bournemouth
#  + 69_MID_Bournemouth + 6_MID_Arsenal + 70_MID_Bournemouth
#  + 71_DEF_Bournemouth + 72_GKP_Bournemouth + 73_DEF_Bournemouth
#  + 74_MID_Bournemouth + 75_MID_Bournemouth + 76_DEF_Bournemouth
#  + 77_GKP_Bournemouth + 78_DEF_Brentford + 79_MID_Brentford + 7_MID_Arsenal
#  + 80_FWD_Brentford + 81_GKP_Brentford + 82_DEF_Brentford + 83_MID_Brentford
#  + 84_DEF_Brentford + 85_DEF_Brentford + 86_MID_Brentford + 87_MID_Brentford
#  + 88_MID_Brentford + 89_MID_Brentford + 8_DEF_Arsenal + 90_DEF_Brentford
#  + 91_DEF_Brentford + 92_DEF_Brentford + 93_MID_Brentford + 94_MID_Brentford
#  + 95_FWD_Brentford + 96_DEF_Brentford + 97_FWD_Brentford + 98_DEF_Brentford
#  + 99_MID_Brentford + 9_MID_Arsenal = 15
#
# _C29: 326_FWD_Man_Utd + 327_GKP_Man_Utd + 328_DEF_Man_Utd + 329_DEF_Man_Utd
#  + 330_DEF_Man_Utd + 331_MID_Man_Utd + 332_DEF_Man_Utd + 333_MID_Man_Utd
#  + 334_DEF_Man_Utd + 335_MID_Man_Utd + 336_MID_Man_Utd + 337_DEF_Man_Utd
#  + 338_MID_Man_Utd + 339_DEF_Man_Utd + 340_MID_Man_Utd + 341_DEF_Man_Utd
#  + 342_DEF_Man_Utd + 343_DEF_Man_Utd + 344_MID_Man_Utd + 345_FWD_Man_Utd
#  + 347_MID_Man_Utd + 348_GKP_Man_Utd + 504_DEF_Man_Utd + 519_MID_Man_Utd <= 3
#
# _C30: 221_DEF_Leeds + 222_DEF_Leeds + 223_MID_Leeds + 224_MID_Leeds
#  + 225_MID_Leeds + 226_DEF_Leeds + 227_FWD_Leeds + 228_DEF_Leeds
#  + 229_MID_Leeds + 230_DEF_Leeds + 231_MID_Leeds + 232_MID_Leeds
# ...
# 0 <= 160_MID_Crystal_Palace <= 1 Integer
# 0 <= 161_MID_Crystal_Palace <= 1 Integer
# 0 <= 162_GKP_Crystal_Palace <= 1 Integer
# 0 <= 163_MID_Crystal_Palace <= 1 Integer
# 0 <= 164_MID_Crystal_Palace <= 1 Integer
# 0 <= 165_DEF_Crystal_Palace <= 1 Integer
# 0 <= 166_FWD_Crystal_Palace <= 1 Integer
# 0 <= 167_DEF_Crystal_Palace <= 1 Integer
# 0 <= 168_FWD_Crystal_Palace <= 1 Integer
# 0 <= 169_MID_Crystal_Palace <= 1 Integer
# 0 <= 16_DEF_Arsenal <= 1 Integer
# 0 <= 170_DEF_Crystal_Palace <= 1 Integer
# 0 <= 171_MID_Crystal_Palace <= 1 Integer
# 0 <= 172_MID_Crystal_Palace <= 1 Integer
# 0 <= 173_MID_Crystal_Palace <= 1 Integer
# 0 <= 174_DEF_Crystal_Palace <= 1 Integer
# 0 <= 175_GKP_Crystal_Palace <= 1 Integer
# 0 <= 176_GKP_Everton <= 1 Integer
# 0 <= 177_FWD_Everton <= 1 Integer
# 0 <= 178_DEF_Everton <= 1 Integer
# 0 <= 179_MID_Everton <= 1 Integer
# 0 <= 17_DEF_Arsenal <= 1 Integer
# 0 <= 180_DEF_Everton <= 1 Integer
# 0 <= 181_MID_Everton <= 1 Integer
# 0 <= 182_GKP_Everton <= 1 Integer
# 0 <= 183_MID_Everton <= 1 Integer
# 0 <= 184_MID_Everton <= 1 Integer
# 0 <= 185_MID_Everton <= 1 Integer
# 0 <= 186_MID_Everton <= 1 Integer
# 0 <= 187_MID_Everton <= 1 Integer
# 0 <= 188_DEF_Everton <= 1 Integer
# 0 <= 189_MID_Everton <= 1 Integer
# 0 <= 18_MID_Arsenal <= 1 Integer
# 0 <= 190_MID_Everton <= 1 Integer
# 0 <= 191_FWD_Everton <= 1 Integer
# 0 <= 192_DEF_Everton <= 1 Integer
# 0 <= 193_DEF_Everton <= 1 Integer
# 0 <= 194_DEF_Everton <= 1 Integer
# 0 <= 195_MID_Everton <= 1 Integer
# 0 <= 196_DEF_Everton <= 1 Integer
# 0 <= 197_DEF_Everton <= 1 Integer
# 0 <= 198_DEF_Everton <= 1 Integer
# 0 <= 199_DEF_Everton <= 1 Integer
# 0 <= 19_MID_Arsenal <= 1 Integer
# 0 <= 1_DEF_Arsenal <= 1 Integer
# 0 <= 200_MID_Fulham <= 1 Integer
# 0 <= 201_DEF_Fulham <= 1 Integer
# 0 <= 202_MID_Fulham <= 1 Integer
# 0 <= 203_MID_Fulham <= 1 Integer
# 0 <= 204_MID_Fulham <= 1 Integer
# 0 <= 205_MID_Fulham <= 1 Integer
# 0 <= 206_DEF_Fulham <= 1 Integer
# 0 <= 207_GKP_Fulham <= 1 Integer
# 0 <= 208_DEF_Fulham <= 1 Integer
# 0 <= 209_DEF_Fulham <= 1 Integer
# 0 <= 20_DEF_Arsenal <= 1 Integer
# 0 <= 210_FWD_Fulham <= 1 Integer
# 0 <= 211_MID_Fulham <= 1 Integer
# 0 <= 212_MID_Fulham <= 1 Integer
# 0 <= 213_GKP_Fulham <= 1 Integer
# 0 <= 214_MID_Fulham <= 1 Integer
# 0 <= 215_DEF_Fulham <= 1 Integer
# 0 <= 216_MID_Fulham <= 1 Integer
# 0 <= 217_DEF_Fulham <= 1 Integer
# 0 <= 218_FWD_Fulham <= 1 Integer
# 0 <= 219_FWD_Fulham <= 1 Integer
# 0 <= 21_MID_Arsenal <= 1 Integer
# 0 <= 220_MID_Fulham <= 1 Integer
# 0 <= 221_DEF_Leeds <= 1 Integer
# 0 <= 222_DEF_Leeds <= 1 Integer
# 0 <= 223_MID_Leeds <= 1 Integer
# 0 <= 224_MID_Leeds <= 1 Integer
# 0 <= 225_MID_Leeds <= 1 Integer
# 0 <= 226_DEF_Leeds <= 1 Integer
# 0 <= 227_FWD_Leeds <= 1 Integer
# 0 <= 228_DEF_Leeds <= 1 Integer
# 0 <= 229_MID_Leeds <= 1 Integer
# 0 <= 22_MID_Arsenal <= 1 Integer
# 0 <= 230_DEF_Leeds <= 1 Integer
# 0 <= 231_MID_Leeds <= 1 Integer
# 0 <= 232_MID_Leeds <= 1 Integer
# 0 <= 233_MID_Leeds <= 1 Integer
# 0 <= 234_MID_Leeds <= 1 Integer
# 0 <= 235_DEF_Leeds <= 1 Integer
# 0 <= 236_GKP_Leeds <= 1 Integer
# 0 <= 237_FWD_Leeds <= 1 Integer
# 0 <= 238_GKP_Leeds <= 1 Integer
# 0 <= 239_DEF_Leeds <= 1 Integer
# 0 <= 23_MID_Arsenal <= 1 Integer
# 0 <= 240_MID_Leeds <= 1 Integer
# 0 <= 241_MID_Leeds <= 1 Integer
# 0 <= 242_FWD_Leeds <= 1 Integer
# 0 <= 243_DEF_Leeds <= 1 Integer
# 0 <= 244_DEF_Leeds <= 1 Integer
# 0 <= 245_MID_Leeds <= 1 Integer
# 0 <= 246_MID_Leeds <= 1 Integer
# 0 <= 247_MID_Leeds <= 1 Integer
# 0 <= 248_GKP_Leicester <= 1 Integer
# 0 <= 249_DEF_Leicester <= 1 Integer
# 0 <= 24_GKP_Arsenal <= 1 Integer
# 0 <= 250_DEF_Leicester <= 1 Integer
# 0 <= 251_MID_Leicester <= 1 Integer
# 0 <= 252_MID_Leicester <= 1 Integer
# 0 <= 253_DEF_Leicester <= 1 Integer
# 0 <= 254_GKP_Leicester <= 1 Integer
# 0 <= 255_FWD_Leicester <= 1 Integer
# 0 <= 256_DEF_Leicester <= 1 Integer
# 0 <= 257_DEF_Leicester <= 1 Integer
# 0 <= 258_DEF_Leicester <= 1 Integer
# 0 <= 259_MID_Leicester <= 1 Integer
# 0 <= 25_MID_Arsenal <= 1 Integer
# 0 <= 260_MID_Leicester <= 1 Integer
# 0 <= 261_MID_Leicester <= 1 Integer
# 0 <= 262_FWD_Leicester <= 1 Integer
# 0 <= 263_MID_Leicester <= 1 Integer
# 0 <= 264_MID_Leicester <= 1 Integer
# 0 <= 265_MID_Leicester <= 1 Integer
# 0 <= 266_MID_Leicester <= 1 Integer
# 0 <= 267_DEF_Leicester <= 1 Integer
# 0 <= 268_DEF_Leicester <= 1 Integer
# 0 <= 269_MID_Leicester <= 1 Integer
# 0 <= 26_DEF_Arsenal <= 1 Integer
# 0 <= 270_DEF_Leicester <= 1 Integer
# 0 <= 271_FWD_Leicester <= 1 Integer
# 0 <= 272_DEF_Leicester <= 1 Integer
# 0 <= 273_DEF_Leicester <= 1 Integer
# 0 <= 274_MID_Liverpool <= 1 Integer
# 0 <= 275_MID_Liverpool <= 1 Integer
# 0 <= 276_DEF_Liverpool <= 1 Integer
# 0 <= 277_MID_Liverpool <= 1 Integer
# 0 <= 278_MID_Liverpool <= 1 Integer
# 0 <= 279_FWD_Liverpool <= 1 Integer
# 0 <= 27_MID_Arsenal <= 1 Integer
# 0 <= 280_DEF_Liverpool <= 1 Integer
# 0 <= 281_GKP_Liverpool <= 1 Integer
# 0 <= 282_MID_Liverpool <= 1 Integer
# 0 <= 283_MID_Liverpool <= 1 Integer
# 0 <= 284_DEF_Liverpool <= 1 Integer
# 0 <= 285_DEF_Liverpool <= 1 Integer
# 0 <= 286_DEF_Liverpool <= 1 Integer
# 0 <= 287_MID_Liverpool <= 1 Integer
# 0 <= 288_FWD_Liverpool <= 1 Integer
# 0 <= 289_GKP_Liverpool <= 1 Integer
# 0 <= 28_FWD_Arsenal <= 1 Integer
# 0 <= 290_DEF_Liverpool <= 1 Integer
# 0 <= 291_MID_Liverpool <= 1 Integer
# 0 <= 292_DEF_Liverpool <= 1 Integer
# 0 <= 293_MID_Liverpool <= 1 Integer
# 0 <= 294_MID_Liverpool <= 1 Integer
# 0 <= 295_DEF_Nott'm_Forest <= 1 Integer
# 0 <= 296_MID_Liverpool <= 1 Integer
# 0 <= 297_FWD_Liverpool <= 1 Integer
# 0 <= 298_DEF_Liverpool <= 1 Integer
# 0 <= 299_DEF_Man_City <= 1 Integer
# 0 <= 29_MID_Aston_Villa <= 1 Integer
# 0 <= 2_GKP_Arsenal <= 1 Integer
# 0 <= 300_MID_Man_City <= 1 Integer
# 0 <= 301_MID_Man_City <= 1 Integer
# 0 <= 302_DEF_Man_City <= 1 Integer
# 0 <= 303_MID_Man_City <= 1 Integer
# 0 <= 304_MID_Chelsea <= 1 Integer
# 0 <= 305_MID_Man_City <= 1 Integer
# 0 <= 306_DEF_Man_City <= 1 Integer
# 0 <= 307_GKP_Man_City <= 1 Integer
# 0 <= 308_DEF_Man_City <= 1 Integer
# 0 <= 309_DEF_Man_City <= 1 Integer
# 0 <= 30_FWD_Aston_Villa <= 1 Integer
# 0 <= 310_GKP_Man_City <= 1 Integer
# 0 <= 311_MID_Man_City <= 1 Integer
# 0 <= 312_DEF_Man_City <= 1 Integer
# 0 <= 313_DEF_Man_City <= 1 Integer
# 0 <= 314_MID_Man_City <= 1 Integer
# 0 <= 315_MID_Man_City <= 1 Integer
# 0 <= 316_MID_Man_City <= 1 Integer
# 0 <= 317_MID_Man_City <= 1 Integer
# 0 <= 318_FWD_Man_City <= 1 Integer
# 0 <= 319_FWD_Man_City <= 1 Integer
# 0 <= 31_GKP_Aston_Villa <= 1 Integer
# 0 <= 320_DEF_Man_City <= 1 Integer
# 0 <= 321_MID_Southampton <= 1 Integer
# 0 <= 322_DEF_Man_City <= 1 Integer
# 0 <= 323_FWD_Man_City <= 1 Integer
# 0 <= 324_GKP_Man_City <= 1 Integer
# 0 <= 325_MID_Man_City <= 1 Integer
# 0 <= 326_FWD_Man_Utd <= 1 Integer
# 0 <= 327_GKP_Man_Utd <= 1 Integer
# 0 <= 328_DEF_Man_Utd <= 1 Integer
# 0 <= 329_DEF_Man_Utd <= 1 Integer
# 0 <= 32_DEF_Aston_Villa <= 1 Integer
# 0 <= 330_DEF_Man_Utd <= 1 Integer
# 0 <= 331_MID_Man_Utd <= 1 Integer
# 0 <= 332_DEF_Man_Utd <= 1 Integer
# 0 <= 333_MID_Man_Utd <= 1 Integer
# 0 <= 334_DEF_Man_Utd <= 1 Integer
# 0 <= 335_MID_Man_Utd <= 1 Integer
# 0 <= 336_MID_Man_Utd <= 1 Integer
# 0 <= 337_DEF_Man_Utd <= 1 Integer
# 0 <= 338_MID_Man_Utd <= 1 Integer
# 0 <= 339_DEF_Man_Utd <= 1 Integer
# 0 <= 33_DEF_Aston_Villa <= 1 Integer
# 0 <= 340_MID_Man_Utd <= 1 Integer
# 0 <= 341_DEF_Man_Utd <= 1 Integer
# 0 <= 342_DEF_Man_Utd <= 1 Integer
# 0 <= 343_DEF_Man_Utd <= 1 Integer
# 0 <= 344_MID_Man_Utd <= 1 Integer
# 0 <= 345_FWD_Man_Utd <= 1 Integer
# 0 <= 346_MID_Fulham <= 1 Integer
# 0 <= 347_MID_Man_Utd <= 1 Integer
# 0 <= 348_GKP_Man_Utd <= 1 Integer
# 0 <= 349_MID_Newcastle <= 1 Integer
# 0 <= 34_MID_Aston_Villa <= 1 Integer
# 0 <= 350_DEF_Newcastle <= 1 Integer
# 0 <= 351_DEF_Newcastle <= 1 Integer
# 0 <= 352_DEF_Newcastle <= 1 Integer
# 0 <= 353_GKP_Newcastle <= 1 Integer
# 0 <= 354_FWD_Newcastle <= 1 Integer
# 0 <= 355_GKP_Newcastle <= 1 Integer
# 0 <= 356_FWD_Newcastle <= 1 Integer
# 0 <= 357_DEF_Newcastle <= 1 Integer
# 0 <= 358_DEF_Newcastle <= 1 Integer
# 0 <= 359_MID_Newcastle <= 1 Integer
# 0 <= 35_GKP_Aston_Villa <= 1 Integer
# 0 <= 360_DEF_Newcastle <= 1 Integer
# 0 <= 361_FWD_Newcastle <= 1 Integer
# 0 <= 362_DEF_Newcastle <= 1 Integer
# 0 <= 363_DEF_Newcastle <= 1 Integer
# 0 <= 364_DEF_Newcastle <= 1 Integer
# 0 <= 365_MID_Newcastle <= 1 Integer
# 0 <= 366_DEF_Newcastle <= 1 Integer
# 0 <= 367_DEF_Newcastle <= 1 Integer
# 0 <= 368_MID_Newcastle <= 1 Integer
# 0 <= 369_MID_Newcastle <= 1 Integer
# 0 <= 36_MID_Aston_Villa <= 1 Integer
# 0 <= 370_MID_Newcastle <= 1 Integer
# 0 <= 371_MID_Newcastle <= 1 Integer
# 0 <= 372_DEF_Newcastle <= 1 Integer
# 0 <= 373_MID_Newcastle <= 1 Integer
# 0 <= 374_MID_Newcastle <= 1 Integer
# 0 <= 375_MID_Newcastle <= 1 Integer
# 0 <= 376_GKP_Newcastle <= 1 Integer
# 0 <= 377_DEF_Newcastle <= 1 Integer
# 0 <= 378_MID_Nott'm_Forest <= 1 Integer
# 0 <= 379_DEF_Nott'm_Forest <= 1 Integer
# 0 <= 37_MID_Aston_Villa <= 1 Integer
# 0 <= 380_FWD_Nott'm_Forest <= 1 Integer
# 0 <= 381_MID_Nott'm_Forest <= 1 Integer
# 0 <= 382_GKP_Nott'm_Forest <= 1 Integer
# 0 <= 383_MID_Nott'm_Forest <= 1 Integer
# 0 <= 384_MID_Nott'm_Forest <= 1 Integer
# 0 <= 385_DEF_Nott'm_Forest <= 1 Integer
# 0 <= 386_DEF_Nott'm_Forest <= 1 Integer
# 0 <= 387_MID_Nott'm_Forest <= 1 Integer
# 0 <= 388_DEF_Nott'm_Forest <= 1 Integer
# 0 <= 389_DEF_Nott'm_Forest <= 1 Integer
# 0 <= 38_DEF_Aston_Villa <= 1 Integer
# 0 <= 390_MID_Nott'm_Forest <= 1 Integer
# 0 <= 391_FWD_Nott'm_Forest <= 1 Integer
# 0 <= 392_DEF_Nott'm_Forest <= 1 Integer
# 0 <= 393_DEF_Nott'm_Forest <= 1 Integer
# 0 <= 394_FWD_Nott'm_Forest <= 1 Integer
# 0 <= 395_MID_Nott'm_Forest <= 1 Integer
# 0 <= 396_MID_Nott'm_Forest <= 1 Integer
# 0 <= 397_FWD_Nott'm_Forest <= 1 Integer
# 0 <= 398_GKP_Nott'm_Forest <= 1 Integer
# 0 <= 399_DEF_Nott'm_Forest <= 1 Integer
# 0 <= 39_DEF_Aston_Villa <= 1 Integer
# 0 <= 3_MID_Arsenal <= 1 Integer
# 0 <= 400_MID_Southampton <= 1 Integer
# 0 <= 401_GKP_Southampton <= 1 Integer
# 0 <= 402_MID_Southampton <= 1 Integer
# 0 <= 403_MID_Southampton <= 1 Integer
# 0 <= 404_DEF_Southampton <= 1 Integer
# 0 <= 405_MID_Southampton <= 1 Integer
# 0 <= 406_MID_Southampton <= 1 Integer
# 0 <= 407_MID_Southampton <= 1 Integer
# 0 <= 408_FWD_Southampton <= 1 Integer
# 0 <= 409_DEF_Southampton <= 1 Integer
# 0 <= 40_FWD_Aston_Villa <= 1 Integer
# 0 <= 410_DEF_Southampton <= 1 Integer
# 0 <= 411_FWD_Southampton <= 1 Integer
# 0 <= 412_MID_Southampton <= 1 Integer
# 0 <= 413_DEF_Southampton <= 1 Integer
# 0 <= 414_DEF_Southampton <= 1 Integer
# 0 <= 415_MID_Southampton <= 1 Integer
# 0 <= 416_MID_Southampton <= 1 Integer
# 0 <= 417_DEF_Southampton <= 1 Integer
# 0 <= 418_MID_Southampton <= 1 Integer
# 0 <= 419_DEF_Southampton <= 1 Integer
# 0 <= 41_MID_Aston_Villa <= 1 Integer
# 0 <= 420_DEF_Southampton <= 1 Integer
# 0 <= 421_GKP_Southampton <= 1 Integer
# 0 <= 422_GKP_Southampton <= 1 Integer
# 0 <= 423_DEF_Southampton <= 1 Integer
# 0 <= 424_GKP_Southampton <= 1 Integer
# 0 <= 425_GKP_Spurs <= 1 Integer
# 0 <= 426_GKP_Spurs <= 1 Integer
# 0 <= 427_FWD_Spurs <= 1 Integer
# 0 <= 428_MID_Spurs <= 1 Integer
# 0 <= 429_DEF_Spurs <= 1 Integer
# 0 <= 42_MID_Aston_Villa <= 1 Integer
# 0 <= 430_DEF_Spurs <= 1 Integer
# 0 <= 431_MID_Spurs <= 1 Integer
# 0 <= 432_DEF_Spurs <= 1 Integer
# 0 <= 433_MID_Spurs <= 1 Integer
# 0 <= 434_MID_Spurs <= 1 Integer
# 0 <= 435_DEF_Spurs <= 1 Integer
# 0 <= 436_DEF_Spurs <= 1 Integer
# 0 <= 437_MID_Spurs <= 1 Integer
# 0 <= 438_DEF_Spurs <= 1 Integer
# 0 <= 439_DEF_Spurs <= 1 Integer
# 0 <= 43_DEF_Aston_Villa <= 1 Integer
# 0 <= 440_MID_Spurs <= 1 Integer
# 0 <= 441_MID_Spurs <= 1 Integer
# 0 <= 442_DEF_Spurs <= 1 Integer
# 0 <= 443_DEF_Spurs <= 1 Integer
# 0 <= 444_MID_Spurs <= 1 Integer
# 0 <= 445_DEF_Spurs <= 1 Integer
# 0 <= 446_MID_Spurs <= 1 Integer
# 0 <= 447_FWD_Spurs <= 1 Integer
# 0 <= 448_DEF_Spurs <= 1 Integer
# 0 <= 449_MID_Spurs <= 1 Integer
# 0 <= 44_DEF_Aston_Villa <= 1 Integer
# 0 <= 450_MID_Spurs <= 1 Integer
# 0 <= 451_GKP_Spurs <= 1 Integer
# 0 <= 452_MID_Spurs <= 1 Integer
# 0 <= 453_FWD_Spurs <= 1 Integer
# 0 <= 454_FWD_Spurs <= 1 Integer
# 0 <= 455_GKP_West_Ham <= 1 Integer
# 0 <= 456_DEF_West_Ham <= 1 Integer
# 0 <= 457_DEF_West_Ham <= 1 Integer
# 0 <= 458_FWD_West_Ham <= 1 Integer
# 0 <= 459_DEF_West_Ham <= 1 Integer
# 0 <= 45_MID_Aston_Villa <= 1 Integer
# 0 <= 460_MID_West_Ham <= 1 Integer
# 0 <= 461_DEF_West_Ham <= 1 Integer
# 0 <= 462_DEF_West_Ham <= 1 Integer
# 0 <= 463_DEF_West_Ham <= 1 Integer
# 0 <= 464_MID_West_Ham <= 1 Integer
# 0 <= 465_MID_West_Ham <= 1 Integer
# 0 <= 466_MID_West_Ham <= 1 Integer
# 0 <= 467_MID_West_Ham <= 1 Integer
# 0 <= 468_MID_West_Ham <= 1 Integer
# 0 <= 469_MID_West_Ham <= 1 Integer
# 0 <= 46_MID_Aston_Villa <= 1 Integer
# 0 <= 470_DEF_West_Ham <= 1 Integer
# 0 <= 471_DEF_West_Ham <= 1 Integer
# 0 <= 472_DEF_West_Ham <= 1 Integer
# 0 <= 473_GKP_West_Ham <= 1 Integer
# 0 <= 474_DEF_Wolves <= 1 Integer
# 0 <= 475_DEF_Wolves <= 1 Integer
# 0 <= 476_FWD_Wolves <= 1 Integer
# 0 <= 477_DEF_Wolves <= 1 Integer
# 0 <= 478_GKP_Wolves <= 1 Integer
# 0 <= 479_MID_Wolves <= 1 Integer
# 0 <= 47_MID_Aston_Villa <= 1 Integer
# 0 <= 480_MID_Wolves <= 1 Integer
# 0 <= 481_MID_Wolves <= 1 Integer
# 0 <= 482_DEF_Wolves <= 1 Integer
# 0 <= 483_MID_Wolves <= 1 Integer
# 0 <= 484_DEF_Wolves <= 1 Integer
# 0 <= 485_MID_Wolves <= 1 Integer
# 0 <= 486_MID_Wolves <= 1 Integer
# 0 <= 487_DEF_Wolves <= 1 Integer
# 0 <= 488_FWD_Wolves <= 1 Integer
# 0 <= 489_DEF_Wolves <= 1 Integer
# 0 <= 48_MID_Aston_Villa <= 1 Integer
# 0 <= 490_MID_Wolves <= 1 Integer
# 0 <= 491_MID_Wolves <= 1 Integer
# 0 <= 492_GKP_Wolves <= 1 Integer
# 0 <= 493_MID_Wolves <= 1 Integer
# 0 <= 494_DEF_Wolves <= 1 Integer
# 0 <= 495_GKP_Crystal_Palace <= 1 Integer
# 0 <= 496_FWD_Crystal_Palace <= 1 Integer
# 0 <= 497_GKP_Liverpool <= 1 Integer
# 0 <= 498_DEF_Liverpool <= 1 Integer
# 0 <= 499_DEF_Liverpool <= 1 Integer
# 0 <= 49_MID_Aston_Villa <= 1 Integer
# 0 <= 4_MID_Arsenal <= 1 Integer
# 0 <= 500_DEF_Liverpool <= 1 Integer
# 0 <= 501_DEF_Liverpool <= 1 Integer
# 0 <= 502_GKP_Man_City <= 1 Integer
# 0 <= 503_MID_Wolves <= 1 Integer
# 0 <= 504_DEF_Man_Utd <= 1 Integer
# 0 <= 505_MID_Bournemouth <= 1 Integer
# 0 <= 506_MID_Leeds <= 1 Integer
# 0 <= 507_DEF_Nott'm_Forest <= 1 Integer
# 0 <= 508_MID_Leeds <= 1 Integer
# 0 <= 509_MID_West_Ham <= 1 Integer
# 0 <= 50_DEF_Aston_Villa <= 1 Integer
# 0 <= 510_DEF_Brentford <= 1 Integer
# 0 <= 511_DEF_Nott'm_Forest <= 1 Integer
# 0 <= 512_MID_Southampton <= 1 Integer
# 0 <= 513_DEF_Spurs <= 1 Integer
# 0 <= 514_MID_Crystal_Palace <= 1 Integer
# 0 <= 515_MID_Brentford <= 1 Integer
# 0 <= 516_DEF_Wolves <= 1 Integer
# 0 <= 517_GKP_Brentford <= 1 Integer
# 0 <= 518_GKP_Nott'm_Forest <= 1 Integer
# 0 <= 519_MID_Man_Utd <= 1 Integer
# 0 <= 51_MID_Aston_Villa <= 1 Integer
# 0 <= 52_FWD_Aston_Villa <= 1 Integer
# 0 <= 53_MID_Aston_Villa <= 1 Integer
# 0 <= 54_FWD_Aston_Villa <= 1 Integer
# 0 <= 55_MID_Aston_Villa <= 1 Integer
# 0 <= 56_DEF_Aston_Villa <= 1 Integer
# 0 <= 57_DEF_Bournemouth <= 1 Integer
# 0 <= 58_MID_Bournemouth <= 1 Integer
# 0 <= 59_DEF_Bournemouth <= 1 Integer
# 0 <= 5_DEF_Arsenal <= 1 Integer
# 0 <= 60_MID_Bournemouth <= 1 Integer
# 0 <= 61_MID_Bournemouth <= 1 Integer
# 0 <= 62_FWD_Bournemouth <= 1 Integer
# 0 <= 63_MID_Bournemouth <= 1 Integer
# 0 <= 64_MID_Bournemouth <= 1 Integer
# 0 <= 65_DEF_Bournemouth <= 1 Integer
# 0 <= 66_FWD_Bournemouth <= 1 Integer
# 0 <= 67_MID_Bournemouth <= 1 Integer
# 0 <= 68_MID_Bournemouth <= 1 Integer
# 0 <= 69_MID_Bournemouth <= 1 Integer
# 0 <= 6_MID_Arsenal <= 1 Integer
# 0 <= 70_MID_Bournemouth <= 1 Integer
# 0 <= 71_DEF_Bournemouth <= 1 Integer
# 0 <= 72_GKP_Bournemouth <= 1 Integer
# 0 <= 73_DEF_Bournemouth <= 1 Integer
# 0 <= 74_MID_Bournemouth <= 1 Integer
# 0 <= 75_MID_Bournemouth <= 1 Integer
# 0 <= 76_DEF_Bournemouth <= 1 Integer
# 0 <= 77_GKP_Bournemouth <= 1 Integer
# 0 <= 78_DEF_Brentford <= 1 Integer
# 0 <= 79_MID_Brentford <= 1 Integer
# 0 <= 7_MID_Arsenal <= 1 Integer
# 0 <= 80_FWD_Brentford <= 1 Integer
# 0 <= 81_GKP_Brentford <= 1 Integer
# 0 <= 82_DEF_Brentford <= 1 Integer
# 0 <= 83_MID_Brentford <= 1 Integer
# 0 <= 84_DEF_Brentford <= 1 Integer
# 0 <= 85_DEF_Brentford <= 1 Integer
# 0 <= 86_MID_Brentford <= 1 Integer
# 0 <= 87_MID_Brentford <= 1 Integer
# 0 <= 88_MID_Brentford <= 1 Integer
# 0 <= 89_MID_Brentford <= 1 Integer
# 0 <= 8_DEF_Arsenal <= 1 Integer
# 0 <= 90_DEF_Brentford <= 1 Integer
# 0 <= 91_DEF_Brentford <= 1 Integer
# 0 <= 92_DEF_Brentford <= 1 Integer
# 0 <= 93_MID_Brentford <= 1 Integer
# 0 <= 94_MID_Brentford <= 1 Integer
# 0 <= 95_FWD_Brentford <= 1 Integer
# 0 <= 96_DEF_Brentford <= 1 Integer
# 0 <= 97_FWD_Brentford <= 1 Integer
# 0 <= 98_DEF_Brentford <= 1 Integer
# 0 <= 99_MID_Brentford <= 1 Integer
# 0 <= 9_MID_Arsenal <= 1 Integer

# %%
status = prob.solve()
print("Status", pulp.LpStatus[status])
print(prob.objective.value())
# Out:
# Status Optimal
# 2383.0

# %%
data['flag'] = data.apply(lambda x: x.variables.value(), axis=1)
data[data.flag == 1].sort_values('element_type_name')
# Out:
#       id                                name element_type_name    team_name  \
# 55    16        Gabriel dos Santos Magalhães               DEF      Arsenal
# 128   43                          Matty Cash               DEF  Aston Villa
# 197  276                          Joel Matip               DEF    Liverpool
# 200  285              Trent Alexander-Arnold               DEF    Liverpool
# 297  306                        João Cancelo               DEF     Man City
# 129   40                       Ollie Watkins               FWD  Aston Villa
# 321   95                        Bryan Mbeumo               FWD    Brentford
# 323   80                          Ivan Toney               FWD    Brentford
# 485  327               David De Gea Quintana               GKP      Man Utd
# 502  281               Alisson Ramses Becker               GKP    Liverpool
# 43    13                         Bukayo Saka               MID      Arsenal
# 145  148                     Conor Gallagher               MID      Chelsea
# 208  407                   James Ward-Prowse               MID  Southampton
# 298  311  Bernardo Veiga de Carvalho e Silva               MID     Man City
# 497  261                      James Maddison               MID    Leicester
#
#      total_points  now_cost            variables  flag
# 55            146        50       16_DEF_Arsenal   1.0
# 128           147        50   43_DEF_Aston_Villa   1.0
# 197           170        60    276_DEF_Liverpool   1.0
# 200           208        75    285_DEF_Liverpool   1.0
# 297           201        70     306_DEF_Man_City   1.0
# 129           131        75   40_FWD_Aston_Villa   1.0
# 321           119        60     95_FWD_Brentford   1.0
# 323           139        70     80_FWD_Brentford   1.0
# 485           132        50      327_GKP_Man_Utd   1.0
# 502           176        55    281_GKP_Liverpool   1.0
# 43            179        80       13_MID_Arsenal   1.0
# 145           140        60      148_MID_Chelsea   1.0
# 208           159        65  407_MID_Southampton   1.0
# 298           155        70     311_MID_Man_City   1.0
# 497           181        80    261_MID_Leicester   1.0
